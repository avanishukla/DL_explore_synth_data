# %%
###install pytorch in colab
# !pip3 install https://download.pytorch.org/whl/cu100/torch-1.1.0-cp36-cp36m-linux_x86_64.whl
# !pip3 install https://download.pytorch.org/whl/cu100/torchvision-0.3.0-cp36-cp36m-linux_x86_64.whl

# %%
##mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import numpy as np
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import json
import pandas as pd
import torch
import time
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.nn.init as init

# %%
base_path = '/content/drive/My Drive/DL_exp/'

# %%
### custom dataset class for dataset. read the csv in __init__ . 
# input : csv file path
# output: returns (data,label)
class load_dataset(Dataset):
    def __init__(self, data_path):
        self.samples = pd.read_csv(data_path).values

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx,:-1] ,self.samples[idx,-1]
      
### Multilayer Perceptron Model
# input : number of features (input), hidden nodes list , number of classes
class MultilayerPerceptron(torch.nn.Module):
  
    def __init__(self,num_features,hidden_nodes_list,num_classes):
        super(MultilayerPerceptron, self).__init__()
        
        num_hidden_layes = len(hidden_nodes_list)
        self.hidden = torch.nn.ModuleList()
        
        self.hidden.append(torch.nn.Linear(num_features, hidden_nodes_list[0]))
        for k in range(num_hidden_layes-1):
            self.hidden.append(torch.nn.Linear(hidden_nodes_list[k], hidden_nodes_list[k+1]))    
        self.hidden.append(torch.nn.Linear(hidden_nodes_list[num_hidden_layes-1], num_classes))
        
    # input : features
    # output: logits , probabilities
    def forward(self, x):
        out = x
        for layer in self.hidden[:-1]:
          out = layer(out)
          out = F.relu(out)

        logits = self.hidden[-1](out)
        probas = F.log_softmax(logits, dim=1)
        return logits, probas
      
### weight initialization function
# use : model.apply(init_weights)
def init_weights(m):
  if isinstance(m, torch.nn.Linear):
    if initialisation_method=='xavier':
      init.xavier_uniform_(m.weight)
    if initialisation_method=='he':
      init.kaiming_uniform_(m.weight)
    m.bias.data.fill_(0.01)
    
### function to compute the accuracy
# input : model, data of type DataLoader
# output: cost (log loss), accuracy 
def compute_accuracy(net, data_loader):
    net.eval()
    cost, correct_pred, num_examples = 0, 0, 0
    with torch.no_grad():
        for features, targets in data_loader:
            features = features.float().to(device)
            targets = targets.long().to(device)
            logits, probas = net(features)
            cost += F.cross_entropy(logits, targets) * targets.size(0)
            _, predicted_labels = torch.max(probas, 1)
            num_examples += targets.size(0)
            correct_pred += (predicted_labels == targets).sum()
        return cost/num_examples , correct_pred.float()/num_examples * 100

# %%
### Training of multiple models
# Input: csv file path contain sphere-shell d dimension features,label data. 
# Its name is like 'train_sp1_sh1.8_t1_2dim.csv' where sphere, shell radius, shell thickness and dimension are variable that have to specify.
radius_of_sphere = 1
radius_of_shell = 1.8
thickness_of_shell = 1
dimentions = [2,4,8,16,32,64]          # list of dimention of the data
# Output: upade 'uniform_result.json' file with the data, trained model details, accuracy, epoch and loss
# also update 'loss.json' file which have list of [{epoch},{loss}] data of trained model 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
start_time = time.time()

with open(base_path+'result/loss.json', mode='r') as readjson:
  try: 
    loss = json.loads(readjson.read())
  except ValueError: 
    loss = {}
          
for dim in dimentions:
  csv_path = base_path+'uniform_data/train_sp'+ str(radius_of_sphere) + '_sh'+ str(radius_of_shell) + '_t' + str(thickness_of_shell)+ '_' + str(dim) + 'dim.csv'
  dataset = load_dataset(csv_path)
  size = len(dataset)
  train_dataloader = DataLoader(dataset, batch_size=size, shuffle=True)


  tmp_h = [2,4,6,8,12,16,24,32,48,64,128,256]             #list of total number of nodes in hidden layers
  tmp_i = [100,200,300,400,500,600,700,800,900,1000]      #list of random seed for weight initialization

  for t_h in tmp_h:
    for t_i in tmp_i:

      #architecture
      num_features  = next(iter(dataset))[0].shape[0]        # Input data dimention
      hidden_nodes_list   = [t_h]                            # List of number of nodes at each hidden layer
      num_classes   = 2                                      # The number of output classes. In this case, 0 and 1
      
      # 'xavier' : Xavier Initialisation
      # 'he' : He Initialisation
      initialisation_method = 'xavier'
      
      # 'sgd' : SGD (lr) 
      # 'sgdwm' : SGD with Momentum (lr, momentum)
      # 'adagrad' : AdaGrad
      # 'adam' : Adam
      # 'ngd' : Natural gradient descent
      # 'l1' : L1 Regularisation
      # 'l2' : L2 Regularisation
      # 'pathnorm' : PathNorm Regularisation
      # 'spectralnorm' : Spectral norm Regularisation
      optimisation_method = 'sgdwm'  

      # Hyperparameters
      random_seed = t_i
      learning_rate = 0.05
            
      torch.manual_seed(random_seed)
      model = MultilayerPerceptron(num_features,hidden_nodes_list,num_classes)
      model.apply(init_weights)
      model = model.to(device)

      if optimisation_method=='sgd' or optimisation_method=='ngd':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
      if optimisation_method=='sgdwm':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
      if optimisation_method=='adagrad':
        optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate)
      if optimisation_method=='adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08)

      model_loss = []
      epoch = 0

      with torch.set_grad_enabled(False):
        cost,best_acc = compute_accuracy(model, train_dataloader)
      model_loss.append([epoch,cost.data.tolist()])
      
      count = 1
      prev_acc=best_acc
      best_epoch = epoch
      best_cost = cost

      while True:
          model.train()
          for batch_idx, (features, targets) in enumerate(train_dataloader):

              features = features.float().to(device)
              targets = targets.long().to(device)

              ### FORWARD AND BACK PROP
              logits, probas = model(features)
              cost = F.cross_entropy(logits, targets)
              optimizer.zero_grad()

              cost.backward()

              ### UPDATE MODEL PARAMETERS
              optimizer.step()


          with torch.set_grad_enabled(False):
              cost,acc = compute_accuracy(model, train_dataloader)
              
          epoch+=1
          model_loss.append([epoch,cost.data.tolist()])
          
          # Stopping conditions
          if prev_acc==acc:
            count+=1
          else:
            prev_acc=acc
            count=1
          if (epoch>50 and best_acc-acc>=5) or count==20 or epoch==400:
            break
          if acc>best_acc:
            best_acc=acc
            best_epoch = epoch
            best_cost = cost
 
      print('Epoch: %03d | Accuracy: %.2f%% | Cost: %.4f' % (best_epoch,best_acc,best_cost))
  
      if len(hidden_nodes_list)==1:
        loss.update({'sh'+ str(radius_of_shell)+'dim'+str(dim)+'h'+str(t_h)+'i'+str(t_i):model_loss})
      else:
        loss.update({'sh'+ str(radius_of_shell)+'dim'+str(dim)+'h'+str(t_h)+'i'+str(t_i)+'l2':model_loss})
    
      with open(base_path+'result/uniform_result.json', mode='r') as readjson:
        try: 
          result = json.loads(readjson.read())
        except ValueError: 
          result = []  
       
      with open(base_path+'result/uniform_result.json', mode='w') as feedjson:
        entry = {'sphere_radius': 1, 'shell_radius': radius_of_shell, 'thickness' : 1, 'dimension':dim, 'n_nodes':hidden_nodes_list, 'random_seed':t_i, 'epoch':best_epoch, 'accuracy':best_acc.data.tolist(), 'cost':best_cost.data.tolist()}
        result.append(entry)
        json.dump(result, feedjson)

with open(base_path+'result/loss.json', mode='w') as feedjson:
  json.dump(loss, feedjson)

# print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 090 | Accuracy: 86.00% | Cost: 0.3393
# Epoch: 193 | Accuracy: 83.80% | Cost: 0.3752
# Epoch: 000 | Accuracy: 56.20% | Cost: 0.7952
# Epoch: 038 | Accuracy: 64.20% | Cost: 0.6830
# Epoch: 205 | Accuracy: 84.00% | Cost: 0.3910
# Epoch: 078 | Accuracy: 83.00% | Cost: 0.4050
# Epoch: 107 | Accuracy: 82.80% | Cost: 0.4165
# Epoch: 118 | Accuracy: 70.20% | Cost: 0.5501
# Epoch: 183 | Accuracy: 86.40% | Cost: 0.3581
# Epoch: 155 | Accuracy: 86.60% | Cost: 0.3412
# Epoch: 151 | Accuracy: 99.40% | Cost: 0.1039
# Epoch: 113 | Accuracy: 99.60% | Cost: 0.1141
# Epoch: 103 | Accuracy: 99.80% | Cost: 0.1397
# Epoch: 151 | Accuracy: 100.00% | Cost: 0.0713
# Epoch: 060 | Accuracy: 100.00% | Cost: 0.1633
# Epoch: 081 | Accuracy: 99.80% | Cost: 0.1322
# Epoch: 160 | Accuracy: 99.80% | Cost: 0.0754
# Epoch: 108 | Accuracy: 100.00% | Cost: 0.1258
# Epoch: 110 | Accuracy: 99.40% | Cost: 0.1076
# Epoch: 061 | Accuracy: 100.00% | Cost: 0.1206
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.1218
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1661
# Epoch: 073 | Accuracy: 100.00% | Cost: 0.1034
# Epoch: 085 | Accuracy: 100.00% | Cost: 0.1181
# Epoch: 057 | Accuracy: 99.60% | Cost: 0.1486
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1406
# Epoch: 094 | Accuracy: 99.80% | Cost: 0.0787
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.2114
# Epoch: 087 | Accuracy: 100.00% | Cost: 0.1198
# Epoch: 067 | Accuracy: 100.00% | Cost: 0.1137
# Epoch: 056 | Accuracy: 100.00% | Cost: 0.1586
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1396
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1177
# Epoch: 067 | Accuracy: 100.00% | Cost: 0.1103
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1849
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1372
# Epoch: 054 | Accuracy: 99.60% | Cost: 0.1780
# Epoch: 053 | Accuracy: 100.00% | Cost: 0.1612
# Epoch: 070 | Accuracy: 100.00% | Cost: 0.1312
# Epoch: 045 | Accuracy: 100.00% | Cost: 0.1577
# Epoch: 030 | Accuracy: 100.00% | Cost: 0.2532
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1810
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1374
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1592
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.1302
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.2238
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.1440
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.1408
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.1553
# Epoch: 051 | Accuracy: 99.60% | Cost: 0.1880
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1461
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.1339
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.1219
# Epoch: 033 | Accuracy: 100.00% | Cost: 0.2310
# Epoch: 050 | Accuracy: 100.00% | Cost: 0.1564
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1331
# Epoch: 025 | Accuracy: 100.00% | Cost: 0.3494
# Epoch: 056 | Accuracy: 100.00% | Cost: 0.1697
# Epoch: 056 | Accuracy: 100.00% | Cost: 0.1131
# Epoch: 053 | Accuracy: 100.00% | Cost: 0.1651
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.1767
# Epoch: 047 | Accuracy: 100.00% | Cost: 0.1635
# Epoch: 050 | Accuracy: 100.00% | Cost: 0.1381
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.1669
# Epoch: 047 | Accuracy: 100.00% | Cost: 0.1607
# Epoch: 046 | Accuracy: 100.00% | Cost: 0.1449
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.2339
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.1838
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1724
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.1815
# Epoch: 044 | Accuracy: 100.00% | Cost: 0.1513
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.1706
# Epoch: 030 | Accuracy: 100.00% | Cost: 0.2454
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.2691
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.2052
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1894
# Epoch: 029 | Accuracy: 100.00% | Cost: 0.2475
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.1688
# Epoch: 048 | Accuracy: 100.00% | Cost: 0.1582
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1782
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.2524
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.2138
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.1413
# Epoch: 030 | Accuracy: 100.00% | Cost: 0.2316
# Epoch: 029 | Accuracy: 100.00% | Cost: 0.2395
# Epoch: 047 | Accuracy: 100.00% | Cost: 0.1398
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1573
# Epoch: 028 | Accuracy: 100.00% | Cost: 0.2547
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.1988
# Epoch: 034 | Accuracy: 100.00% | Cost: 0.2073
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.1733
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.2036
# Epoch: 026 | Accuracy: 100.00% | Cost: 0.2836
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.2090
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.1805
# Epoch: 025 | Accuracy: 100.00% | Cost: 0.3236
# Epoch: 025 | Accuracy: 100.00% | Cost: 0.2923
# Epoch: 036 | Accuracy: 100.00% | Cost: 0.1958
# Epoch: 033 | Accuracy: 100.00% | Cost: 0.2091
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.1855
# Epoch: 036 | Accuracy: 100.00% | Cost: 0.1887
# Epoch: 023 | Accuracy: 100.00% | Cost: 0.3075
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.1748
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.1630
# Epoch: 024 | Accuracy: 100.00% | Cost: 0.3033
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.1719
# Epoch: 033 | Accuracy: 100.00% | Cost: 0.1944
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.1866
# Epoch: 026 | Accuracy: 100.00% | Cost: 0.2789
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.1890
# Epoch: 024 | Accuracy: 100.00% | Cost: 0.2987
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.2587
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.1926
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.2600
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.1728
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.2514
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.2119
# Epoch: 033 | Accuracy: 100.00% | Cost: 0.2064
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.1769
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.1715
# Epoch: 132 | Accuracy: 84.40% | Cost: 0.3754
# Epoch: 098 | Accuracy: 83.60% | Cost: 0.4025
# Epoch: 161 | Accuracy: 82.40% | Cost: 0.4371
# Epoch: 155 | Accuracy: 82.60% | Cost: 0.4198
# Epoch: 224 | Accuracy: 80.60% | Cost: 0.4347
# Epoch: 208 | Accuracy: 81.60% | Cost: 0.4114
# Epoch: 090 | Accuracy: 65.40% | Cost: 0.6112
# Epoch: 074 | Accuracy: 82.40% | Cost: 0.4339
# Epoch: 223 | Accuracy: 82.60% | Cost: 0.4127
# Epoch: 155 | Accuracy: 81.40% | Cost: 0.4363
# Epoch: 202 | Accuracy: 94.20% | Cost: 0.1645
# Epoch: 144 | Accuracy: 95.40% | Cost: 0.1626
# Epoch: 301 | Accuracy: 90.60% | Cost: 0.2441
# Epoch: 227 | Accuracy: 96.60% | Cost: 0.1345
# Epoch: 310 | Accuracy: 95.40% | Cost: 0.1253
# Epoch: 159 | Accuracy: 89.60% | Cost: 0.2436
# Epoch: 115 | Accuracy: 90.20% | Cost: 0.2728
# Epoch: 241 | Accuracy: 94.60% | Cost: 0.1435
# Epoch: 232 | Accuracy: 93.80% | Cost: 0.1687
# Epoch: 177 | Accuracy: 88.40% | Cost: 0.2701
# Epoch: 146 | Accuracy: 99.40% | Cost: 0.0897
# Epoch: 136 | Accuracy: 97.00% | Cost: 0.1518
# Epoch: 201 | Accuracy: 98.20% | Cost: 0.0865
# Epoch: 184 | Accuracy: 99.40% | Cost: 0.0687
# Epoch: 142 | Accuracy: 99.60% | Cost: 0.1021
# Epoch: 163 | Accuracy: 99.60% | Cost: 0.0885
# Epoch: 224 | Accuracy: 99.40% | Cost: 0.0950
# Epoch: 127 | Accuracy: 95.60% | Cost: 0.1620
# Epoch: 179 | Accuracy: 100.00% | Cost: 0.0729
# Epoch: 110 | Accuracy: 99.80% | Cost: 0.1135
# Epoch: 101 | Accuracy: 99.60% | Cost: 0.1246
# Epoch: 083 | Accuracy: 99.80% | Cost: 0.1508
# Epoch: 140 | Accuracy: 100.00% | Cost: 0.0746
# Epoch: 145 | Accuracy: 100.00% | Cost: 0.0742
# Epoch: 170 | Accuracy: 99.20% | Cost: 0.0847
# Epoch: 143 | Accuracy: 99.40% | Cost: 0.0746
# Epoch: 069 | Accuracy: 99.80% | Cost: 0.1575
# Epoch: 088 | Accuracy: 99.80% | Cost: 0.1353
# Epoch: 138 | Accuracy: 99.00% | Cost: 0.0986
# Epoch: 174 | Accuracy: 99.80% | Cost: 0.0858
# Epoch: 084 | Accuracy: 100.00% | Cost: 0.1288
# Epoch: 108 | Accuracy: 99.60% | Cost: 0.1136
# Epoch: 150 | Accuracy: 99.60% | Cost: 0.0888
# Epoch: 129 | Accuracy: 100.00% | Cost: 0.0898
# Epoch: 117 | Accuracy: 99.60% | Cost: 0.0909
# Epoch: 075 | Accuracy: 99.80% | Cost: 0.1509
# Epoch: 098 | Accuracy: 99.80% | Cost: 0.0909
# Epoch: 132 | Accuracy: 99.80% | Cost: 0.0910
# Epoch: 085 | Accuracy: 99.80% | Cost: 0.1056
# Epoch: 091 | Accuracy: 99.60% | Cost: 0.1301
# Epoch: 068 | Accuracy: 100.00% | Cost: 0.1379
# Epoch: 099 | Accuracy: 99.80% | Cost: 0.1152
# Epoch: 089 | Accuracy: 99.80% | Cost: 0.1228
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.1155
# Epoch: 102 | Accuracy: 100.00% | Cost: 0.0903
# Epoch: 055 | Accuracy: 99.80% | Cost: 0.2018
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.1092
# Epoch: 086 | Accuracy: 100.00% | Cost: 0.1071
# Epoch: 076 | Accuracy: 99.20% | Cost: 0.1478
# Epoch: 096 | Accuracy: 100.00% | Cost: 0.1117
# Epoch: 085 | Accuracy: 100.00% | Cost: 0.1077
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.1533
# Epoch: 065 | Accuracy: 99.80% | Cost: 0.1445
# Epoch: 045 | Accuracy: 99.80% | Cost: 0.1906
# Epoch: 056 | Accuracy: 100.00% | Cost: 0.1782
# Epoch: 085 | Accuracy: 100.00% | Cost: 0.1159
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.1505
# Epoch: 046 | Accuracy: 99.20% | Cost: 0.1996
# Epoch: 083 | Accuracy: 100.00% | Cost: 0.1240
# Epoch: 056 | Accuracy: 99.60% | Cost: 0.1602
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1773
# Epoch: 035 | Accuracy: 99.80% | Cost: 0.2307
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.1250
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.1449
# Epoch: 055 | Accuracy: 99.80% | Cost: 0.1561
# Epoch: 062 | Accuracy: 100.00% | Cost: 0.1356
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1518
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1770
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1672
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.1300
# Epoch: 069 | Accuracy: 100.00% | Cost: 0.1166
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.1673
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.1411
# Epoch: 066 | Accuracy: 100.00% | Cost: 0.1218
# Epoch: 027 | Accuracy: 99.80% | Cost: 0.3521
# Epoch: 066 | Accuracy: 100.00% | Cost: 0.1322
# Epoch: 048 | Accuracy: 100.00% | Cost: 0.1902
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1951
# Epoch: 045 | Accuracy: 100.00% | Cost: 0.1806
# Epoch: 085 | Accuracy: 100.00% | Cost: 0.0961
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.2131
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1985
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.1866
# Epoch: 031 | Accuracy: 99.80% | Cost: 0.2786
# Epoch: 071 | Accuracy: 100.00% | Cost: 0.1240
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1624
# Epoch: 044 | Accuracy: 100.00% | Cost: 0.1969
# Epoch: 069 | Accuracy: 100.00% | Cost: 0.1269
# Epoch: 046 | Accuracy: 100.00% | Cost: 0.1922
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1634
# Epoch: 034 | Accuracy: 100.00% | Cost: 0.2432
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.3007
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1928
# Epoch: 046 | Accuracy: 100.00% | Cost: 0.1871
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.2322
# Epoch: 041 | Accuracy: 100.00% | Cost: 0.2140
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.1706
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1985
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1991
# Epoch: 045 | Accuracy: 100.00% | Cost: 0.1973
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.2413
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.3171
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.2078
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.2064
# Epoch: 041 | Accuracy: 100.00% | Cost: 0.2048
# Epoch: 041 | Accuracy: 100.00% | Cost: 0.2041
# Epoch: 026 | Accuracy: 100.00% | Cost: 0.3401
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1967
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.2116
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.3093
# Epoch: 315 | Accuracy: 85.60% | Cost: 0.3671
# Epoch: 387 | Accuracy: 82.80% | Cost: 0.3848
# Epoch: 258 | Accuracy: 68.80% | Cost: 0.5705
# Epoch: 212 | Accuracy: 85.20% | Cost: 0.3795
# Epoch: 337 | Accuracy: 84.80% | Cost: 0.3779
# Epoch: 197 | Accuracy: 84.00% | Cost: 0.3865
# Epoch: 233 | Accuracy: 84.40% | Cost: 0.3981
# Epoch: 177 | Accuracy: 83.00% | Cost: 0.4045
# Epoch: 177 | Accuracy: 68.00% | Cost: 0.5833
# Epoch: 189 | Accuracy: 69.20% | Cost: 0.5779
# Epoch: 283 | Accuracy: 92.80% | Cost: 0.1700
# Epoch: 126 | Accuracy: 94.40% | Cost: 0.1954
# Epoch: 258 | Accuracy: 94.00% | Cost: 0.1797
# Epoch: 170 | Accuracy: 93.80% | Cost: 0.1873
# Epoch: 250 | Accuracy: 91.80% | Cost: 0.2116
# Epoch: 238 | Accuracy: 94.20% | Cost: 0.1533
# Epoch: 198 | Accuracy: 95.60% | Cost: 0.1654
# Epoch: 211 | Accuracy: 89.20% | Cost: 0.2614
# Epoch: 205 | Accuracy: 90.80% | Cost: 0.2478
# Epoch: 205 | Accuracy: 93.40% | Cost: 0.1885
# Epoch: 185 | Accuracy: 98.00% | Cost: 0.1097
# Epoch: 290 | Accuracy: 98.00% | Cost: 0.0970
# Epoch: 195 | Accuracy: 97.20% | Cost: 0.1317
# Epoch: 231 | Accuracy: 97.40% | Cost: 0.1222
# Epoch: 191 | Accuracy: 98.40% | Cost: 0.1082
# Epoch: 247 | Accuracy: 97.00% | Cost: 0.1070
# Epoch: 169 | Accuracy: 98.60% | Cost: 0.1115
# Epoch: 323 | Accuracy: 98.60% | Cost: 0.0826
# Epoch: 232 | Accuracy: 98.60% | Cost: 0.0970
# Epoch: 320 | Accuracy: 97.60% | Cost: 0.1018
# Epoch: 185 | Accuracy: 98.40% | Cost: 0.1030
# Epoch: 153 | Accuracy: 98.40% | Cost: 0.1048
# Epoch: 230 | Accuracy: 98.20% | Cost: 0.1067
# Epoch: 203 | Accuracy: 99.20% | Cost: 0.0805
# Epoch: 215 | Accuracy: 98.60% | Cost: 0.1029
# Epoch: 258 | Accuracy: 98.20% | Cost: 0.0863
# Epoch: 141 | Accuracy: 97.40% | Cost: 0.1393
# Epoch: 220 | Accuracy: 98.80% | Cost: 0.0882
# Epoch: 205 | Accuracy: 99.20% | Cost: 0.0954
# Epoch: 167 | Accuracy: 96.60% | Cost: 0.1315
# Epoch: 134 | Accuracy: 97.20% | Cost: 0.1310
# Epoch: 165 | Accuracy: 99.40% | Cost: 0.0820
# Epoch: 092 | Accuracy: 99.20% | Cost: 0.1269
# Epoch: 127 | Accuracy: 99.20% | Cost: 0.1142
# Epoch: 108 | Accuracy: 98.60% | Cost: 0.1434
# Epoch: 140 | Accuracy: 99.40% | Cost: 0.1161
# Epoch: 171 | Accuracy: 98.20% | Cost: 0.1080
# Epoch: 141 | Accuracy: 98.60% | Cost: 0.1117
# Epoch: 093 | Accuracy: 98.40% | Cost: 0.1505
# Epoch: 170 | Accuracy: 99.40% | Cost: 0.0774
# Epoch: 088 | Accuracy: 98.60% | Cost: 0.1625
# Epoch: 064 | Accuracy: 97.80% | Cost: 0.2273
# Epoch: 158 | Accuracy: 99.20% | Cost: 0.0814
# Epoch: 061 | Accuracy: 99.00% | Cost: 0.1771
# Epoch: 145 | Accuracy: 99.40% | Cost: 0.0976
# Epoch: 133 | Accuracy: 99.20% | Cost: 0.0909
# Epoch: 108 | Accuracy: 99.20% | Cost: 0.1082
# Epoch: 089 | Accuracy: 98.80% | Cost: 0.1383
# Epoch: 122 | Accuracy: 99.20% | Cost: 0.1178
# Epoch: 115 | Accuracy: 99.40% | Cost: 0.1095
# Epoch: 096 | Accuracy: 99.80% | Cost: 0.1282
# Epoch: 078 | Accuracy: 99.60% | Cost: 0.1448
# Epoch: 090 | Accuracy: 99.60% | Cost: 0.1310
# Epoch: 088 | Accuracy: 100.00% | Cost: 0.1238
# Epoch: 097 | Accuracy: 99.60% | Cost: 0.1174
# Epoch: 101 | Accuracy: 100.00% | Cost: 0.1119
# Epoch: 068 | Accuracy: 99.80% | Cost: 0.1486
# Epoch: 093 | Accuracy: 100.00% | Cost: 0.1272
# Epoch: 100 | Accuracy: 99.80% | Cost: 0.1037
# Epoch: 080 | Accuracy: 99.20% | Cost: 0.1294
# Epoch: 052 | Accuracy: 98.80% | Cost: 0.2177
# Epoch: 078 | Accuracy: 99.80% | Cost: 0.1504
# Epoch: 074 | Accuracy: 99.40% | Cost: 0.1430
# Epoch: 071 | Accuracy: 100.00% | Cost: 0.1316
# Epoch: 113 | Accuracy: 100.00% | Cost: 0.0958
# Epoch: 079 | Accuracy: 99.80% | Cost: 0.1357
# Epoch: 081 | Accuracy: 99.60% | Cost: 0.1196
# Epoch: 084 | Accuracy: 99.40% | Cost: 0.1327
# Epoch: 082 | Accuracy: 99.60% | Cost: 0.1190
# Epoch: 085 | Accuracy: 99.80% | Cost: 0.1046
# Epoch: 091 | Accuracy: 100.00% | Cost: 0.1079
# Epoch: 071 | Accuracy: 99.80% | Cost: 0.1381
# Epoch: 086 | Accuracy: 99.80% | Cost: 0.1116
# Epoch: 067 | Accuracy: 100.00% | Cost: 0.1468
# Epoch: 074 | Accuracy: 100.00% | Cost: 0.1370
# Epoch: 074 | Accuracy: 99.80% | Cost: 0.1351
# Epoch: 070 | Accuracy: 99.80% | Cost: 0.1485
# Epoch: 098 | Accuracy: 100.00% | Cost: 0.1029
# Epoch: 106 | Accuracy: 99.80% | Cost: 0.0881
# Epoch: 065 | Accuracy: 100.00% | Cost: 0.1372
# Epoch: 063 | Accuracy: 99.80% | Cost: 0.1620
# Epoch: 068 | Accuracy: 99.80% | Cost: 0.1460
# Epoch: 062 | Accuracy: 100.00% | Cost: 0.1621
# Epoch: 058 | Accuracy: 100.00% | Cost: 0.1618
# Epoch: 059 | Accuracy: 99.80% | Cost: 0.1651
# Epoch: 050 | Accuracy: 99.40% | Cost: 0.2037
# Epoch: 069 | Accuracy: 100.00% | Cost: 0.1424
# Epoch: 047 | Accuracy: 99.20% | Cost: 0.2339
# Epoch: 048 | Accuracy: 99.80% | Cost: 0.2114
# Epoch: 069 | Accuracy: 99.80% | Cost: 0.1408
# Epoch: 087 | Accuracy: 100.00% | Cost: 0.1016
# Epoch: 063 | Accuracy: 100.00% | Cost: 0.1472
# Epoch: 076 | Accuracy: 100.00% | Cost: 0.1225
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.1404
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.1799
# Epoch: 054 | Accuracy: 99.80% | Cost: 0.1824
# Epoch: 048 | Accuracy: 100.00% | Cost: 0.1943
# Epoch: 049 | Accuracy: 99.80% | Cost: 0.2042
# Epoch: 051 | Accuracy: 99.80% | Cost: 0.1884
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.1432
# Epoch: 047 | Accuracy: 100.00% | Cost: 0.1904
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.2300
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.1785
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1746
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.2237
# Epoch: 060 | Accuracy: 100.00% | Cost: 0.1531
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.2008
# Epoch: 044 | Accuracy: 99.80% | Cost: 0.2185
# Epoch: 048 | Accuracy: 99.80% | Cost: 0.1926
# Epoch: 048 | Accuracy: 100.00% | Cost: 0.1828
# Epoch: 240 | Accuracy: 82.80% | Cost: 0.4722
# Epoch: 365 | Accuracy: 85.20% | Cost: 0.3816
# Epoch: 220 | Accuracy: 83.00% | Cost: 0.4424
# Epoch: 239 | Accuracy: 85.40% | Cost: 0.3905
# Epoch: 327 | Accuracy: 85.60% | Cost: 0.3646
# Epoch: 367 | Accuracy: 85.60% | Cost: 0.3879
# Epoch: 255 | Accuracy: 83.40% | Cost: 0.4083
# Epoch: 261 | Accuracy: 71.00% | Cost: 0.5603
# Epoch: 324 | Accuracy: 84.60% | Cost: 0.3722
# Epoch: 313 | Accuracy: 82.60% | Cost: 0.4263
# Epoch: 343 | Accuracy: 94.60% | Cost: 0.1788
# Epoch: 312 | Accuracy: 90.00% | Cost: 0.2421
# Epoch: 322 | Accuracy: 89.80% | Cost: 0.2889
# Epoch: 221 | Accuracy: 91.80% | Cost: 0.2549
# Epoch: 306 | Accuracy: 97.40% | Cost: 0.1258
# Epoch: 201 | Accuracy: 93.40% | Cost: 0.2480
# Epoch: 225 | Accuracy: 95.20% | Cost: 0.1682
# Epoch: 399 | Accuracy: 95.20% | Cost: 0.1768
# Epoch: 258 | Accuracy: 97.00% | Cost: 0.1328
# Epoch: 207 | Accuracy: 95.40% | Cost: 0.1678
# Epoch: 273 | Accuracy: 96.20% | Cost: 0.1484
# Epoch: 331 | Accuracy: 96.80% | Cost: 0.1258
# Epoch: 249 | Accuracy: 98.60% | Cost: 0.1112
# Epoch: 257 | Accuracy: 98.80% | Cost: 0.1128
# Epoch: 242 | Accuracy: 97.00% | Cost: 0.1478
# Epoch: 384 | Accuracy: 99.20% | Cost: 0.0846
# Epoch: 136 | Accuracy: 96.60% | Cost: 0.1992
# Epoch: 215 | Accuracy: 97.00% | Cost: 0.1356
# Epoch: 234 | Accuracy: 97.40% | Cost: 0.1256
# Epoch: 198 | Accuracy: 97.00% | Cost: 0.1539
# Epoch: 257 | Accuracy: 95.40% | Cost: 0.1592
# Epoch: 221 | Accuracy: 98.80% | Cost: 0.1040
# Epoch: 119 | Accuracy: 97.00% | Cost: 0.1809
# Epoch: 166 | Accuracy: 96.80% | Cost: 0.1545
# Epoch: 198 | Accuracy: 99.20% | Cost: 0.1160
# Epoch: 227 | Accuracy: 97.80% | Cost: 0.1279
# Epoch: 210 | Accuracy: 98.20% | Cost: 0.1222
# Epoch: 223 | Accuracy: 98.80% | Cost: 0.1134
# Epoch: 183 | Accuracy: 99.00% | Cost: 0.1363
# Epoch: 153 | Accuracy: 98.40% | Cost: 0.1460
# Epoch: 232 | Accuracy: 99.80% | Cost: 0.0840
# Epoch: 131 | Accuracy: 97.80% | Cost: 0.1392
# Epoch: 156 | Accuracy: 100.00% | Cost: 0.1125
# Epoch: 121 | Accuracy: 100.00% | Cost: 0.1275
# Epoch: 196 | Accuracy: 100.00% | Cost: 0.0940
# Epoch: 159 | Accuracy: 99.40% | Cost: 0.0961
# Epoch: 156 | Accuracy: 98.00% | Cost: 0.1281
# Epoch: 121 | Accuracy: 98.60% | Cost: 0.1715
# Epoch: 154 | Accuracy: 99.00% | Cost: 0.1256
# Epoch: 144 | Accuracy: 98.40% | Cost: 0.1333
# Epoch: 124 | Accuracy: 99.20% | Cost: 0.1601
# Epoch: 140 | Accuracy: 99.60% | Cost: 0.1172
# Epoch: 106 | Accuracy: 99.00% | Cost: 0.1850
# Epoch: 162 | Accuracy: 99.80% | Cost: 0.1029
# Epoch: 132 | Accuracy: 99.00% | Cost: 0.1298
# Epoch: 133 | Accuracy: 99.20% | Cost: 0.1336
# Epoch: 125 | Accuracy: 99.20% | Cost: 0.1427
# Epoch: 140 | Accuracy: 97.80% | Cost: 0.1490
# Epoch: 141 | Accuracy: 99.00% | Cost: 0.1173
# Epoch: 105 | Accuracy: 98.20% | Cost: 0.1682
# Epoch: 104 | Accuracy: 99.80% | Cost: 0.1346
# Epoch: 132 | Accuracy: 99.60% | Cost: 0.1176
# Epoch: 132 | Accuracy: 99.80% | Cost: 0.1080
# Epoch: 115 | Accuracy: 99.60% | Cost: 0.1211
# Epoch: 109 | Accuracy: 100.00% | Cost: 0.1371
# Epoch: 088 | Accuracy: 97.80% | Cost: 0.2168
# Epoch: 113 | Accuracy: 99.40% | Cost: 0.1408
# Epoch: 112 | Accuracy: 99.80% | Cost: 0.1345
# Epoch: 082 | Accuracy: 98.80% | Cost: 0.1905
# Epoch: 101 | Accuracy: 99.60% | Cost: 0.1488
# Epoch: 145 | Accuracy: 99.80% | Cost: 0.0996
# Epoch: 098 | Accuracy: 100.00% | Cost: 0.1202
# Epoch: 113 | Accuracy: 100.00% | Cost: 0.1172
# Epoch: 076 | Accuracy: 99.60% | Cost: 0.1796
# Epoch: 129 | Accuracy: 100.00% | Cost: 0.0985
# Epoch: 042 | Accuracy: 98.40% | Cost: 0.3151
# Epoch: 098 | Accuracy: 99.80% | Cost: 0.1420
# Epoch: 110 | Accuracy: 99.60% | Cost: 0.1307
# Epoch: 071 | Accuracy: 99.40% | Cost: 0.2097
# Epoch: 099 | Accuracy: 99.60% | Cost: 0.1355
# Epoch: 056 | Accuracy: 98.60% | Cost: 0.2512
# Epoch: 070 | Accuracy: 99.80% | Cost: 0.1690
# Epoch: 084 | Accuracy: 99.80% | Cost: 0.1472
# Epoch: 092 | Accuracy: 99.80% | Cost: 0.1390
# Epoch: 072 | Accuracy: 99.60% | Cost: 0.1756
# Epoch: 071 | Accuracy: 99.80% | Cost: 0.1705
# Epoch: 045 | Accuracy: 98.80% | Cost: 0.2861
# Epoch: 087 | Accuracy: 100.00% | Cost: 0.1551
# Epoch: 091 | Accuracy: 100.00% | Cost: 0.1384
# Epoch: 069 | Accuracy: 100.00% | Cost: 0.1792
# Epoch: 091 | Accuracy: 100.00% | Cost: 0.1338
# Epoch: 054 | Accuracy: 99.40% | Cost: 0.2239
# Epoch: 080 | Accuracy: 100.00% | Cost: 0.1453
# Epoch: 092 | Accuracy: 100.00% | Cost: 0.1278
# Epoch: 076 | Accuracy: 99.80% | Cost: 0.1546
# Epoch: 049 | Accuracy: 99.60% | Cost: 0.2455
# Epoch: 099 | Accuracy: 99.80% | Cost: 0.1215
# Epoch: 071 | Accuracy: 100.00% | Cost: 0.1739
# Epoch: 078 | Accuracy: 99.80% | Cost: 0.1573
# Epoch: 066 | Accuracy: 100.00% | Cost: 0.1804
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.1772
# Epoch: 058 | Accuracy: 99.80% | Cost: 0.1978
# Epoch: 054 | Accuracy: 99.80% | Cost: 0.2349
# Epoch: 095 | Accuracy: 100.00% | Cost: 0.1139
# Epoch: 081 | Accuracy: 100.00% | Cost: 0.1367
# Epoch: 028 | Accuracy: 100.00% | Cost: 0.3803
# Epoch: 063 | Accuracy: 99.60% | Cost: 0.1790
# Epoch: 041 | Accuracy: 99.60% | Cost: 0.2681
# Epoch: 069 | Accuracy: 99.80% | Cost: 0.1674
# Epoch: 048 | Accuracy: 99.40% | Cost: 0.2420
# Epoch: 069 | Accuracy: 100.00% | Cost: 0.1622
# Epoch: 085 | Accuracy: 100.00% | Cost: 0.1224
# Epoch: 023 | Accuracy: 99.60% | Cost: 0.4046
# Epoch: 025 | Accuracy: 99.40% | Cost: 0.3885
# Epoch: 062 | Accuracy: 99.80% | Cost: 0.1739
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1855
# Epoch: 034 | Accuracy: 99.80% | Cost: 0.3052
# Epoch: 043 | Accuracy: 99.80% | Cost: 0.2601
# Epoch: 056 | Accuracy: 99.80% | Cost: 0.1958
# Epoch: 062 | Accuracy: 99.80% | Cost: 0.1730
# Epoch: 343 | Accuracy: 87.80% | Cost: 0.3420
# Epoch: 293 | Accuracy: 87.80% | Cost: 0.3277
# Epoch: 399 | Accuracy: 88.20% | Cost: 0.3414
# Epoch: 360 | Accuracy: 71.80% | Cost: 0.5349
# Epoch: 358 | Accuracy: 88.20% | Cost: 0.3461
# Epoch: 394 | Accuracy: 89.20% | Cost: 0.3059
# Epoch: 313 | Accuracy: 89.80% | Cost: 0.3088
# Epoch: 331 | Accuracy: 88.00% | Cost: 0.3585
# Epoch: 257 | Accuracy: 86.80% | Cost: 0.3829
# Epoch: 364 | Accuracy: 85.00% | Cost: 0.3512
# Epoch: 237 | Accuracy: 97.00% | Cost: 0.1923
# Epoch: 268 | Accuracy: 96.20% | Cost: 0.1468
# Epoch: 363 | Accuracy: 94.00% | Cost: 0.1984
# Epoch: 378 | Accuracy: 96.80% | Cost: 0.1536
# Epoch: 173 | Accuracy: 94.20% | Cost: 0.2638
# Epoch: 339 | Accuracy: 97.80% | Cost: 0.1326
# Epoch: 371 | Accuracy: 98.20% | Cost: 0.1181
# Epoch: 241 | Accuracy: 97.60% | Cost: 0.1542
# Epoch: 276 | Accuracy: 98.40% | Cost: 0.1311
# Epoch: 273 | Accuracy: 92.80% | Cost: 0.2263
# Epoch: 323 | Accuracy: 100.00% | Cost: 0.0766
# Epoch: 183 | Accuracy: 97.00% | Cost: 0.1577
# Epoch: 257 | Accuracy: 98.00% | Cost: 0.1359
# Epoch: 171 | Accuracy: 97.80% | Cost: 0.1781
# Epoch: 284 | Accuracy: 98.00% | Cost: 0.1347
# Epoch: 206 | Accuracy: 98.40% | Cost: 0.1359
# Epoch: 202 | Accuracy: 97.40% | Cost: 0.1680
# Epoch: 177 | Accuracy: 97.20% | Cost: 0.1882
# Epoch: 218 | Accuracy: 96.20% | Cost: 0.1808
# Epoch: 238 | Accuracy: 98.80% | Cost: 0.1366
# Epoch: 173 | Accuracy: 99.00% | Cost: 0.1365
# Epoch: 224 | Accuracy: 99.60% | Cost: 0.1098
# Epoch: 168 | Accuracy: 98.80% | Cost: 0.1527
# Epoch: 332 | Accuracy: 99.60% | Cost: 0.0738
# Epoch: 182 | Accuracy: 99.20% | Cost: 0.1310
# Epoch: 174 | Accuracy: 99.20% | Cost: 0.1393
# Epoch: 233 | Accuracy: 99.40% | Cost: 0.1013
# Epoch: 211 | Accuracy: 98.20% | Cost: 0.1422
# Epoch: 154 | Accuracy: 97.20% | Cost: 0.1882
# Epoch: 194 | Accuracy: 99.00% | Cost: 0.1408
# Epoch: 207 | Accuracy: 99.40% | Cost: 0.1040
# Epoch: 163 | Accuracy: 98.60% | Cost: 0.1547
# Epoch: 175 | Accuracy: 99.60% | Cost: 0.1103
# Epoch: 178 | Accuracy: 99.20% | Cost: 0.1304
# Epoch: 168 | Accuracy: 99.20% | Cost: 0.1239
# Epoch: 112 | Accuracy: 98.60% | Cost: 0.2130
# Epoch: 143 | Accuracy: 98.40% | Cost: 0.1700
# Epoch: 147 | Accuracy: 99.20% | Cost: 0.1471
# Epoch: 148 | Accuracy: 98.20% | Cost: 0.1482
# Epoch: 205 | Accuracy: 99.60% | Cost: 0.0944
# Epoch: 174 | Accuracy: 99.60% | Cost: 0.1175
# Epoch: 129 | Accuracy: 99.20% | Cost: 0.1501
# Epoch: 130 | Accuracy: 99.40% | Cost: 0.1540
# Epoch: 177 | Accuracy: 99.40% | Cost: 0.1069
# Epoch: 130 | Accuracy: 99.00% | Cost: 0.1521
# Epoch: 139 | Accuracy: 99.80% | Cost: 0.1491
# Epoch: 161 | Accuracy: 99.80% | Cost: 0.1075
# Epoch: 138 | Accuracy: 100.00% | Cost: 0.1341
# Epoch: 153 | Accuracy: 99.60% | Cost: 0.1347
# Epoch: 137 | Accuracy: 98.80% | Cost: 0.1532
# Epoch: 070 | Accuracy: 98.80% | Cost: 0.2574
# Epoch: 100 | Accuracy: 99.60% | Cost: 0.1812
# Epoch: 138 | Accuracy: 99.80% | Cost: 0.1323
# Epoch: 068 | Accuracy: 98.00% | Cost: 0.2692
# Epoch: 111 | Accuracy: 99.40% | Cost: 0.1658
# Epoch: 106 | Accuracy: 99.40% | Cost: 0.1737
# Epoch: 107 | Accuracy: 99.40% | Cost: 0.1703
# Epoch: 146 | Accuracy: 100.00% | Cost: 0.1225
# Epoch: 106 | Accuracy: 99.60% | Cost: 0.1708
# Epoch: 145 | Accuracy: 99.80% | Cost: 0.1235
# Epoch: 117 | Accuracy: 99.80% | Cost: 0.1505
# Epoch: 097 | Accuracy: 98.60% | Cost: 0.1814
# Epoch: 122 | Accuracy: 99.80% | Cost: 0.1232
# Epoch: 137 | Accuracy: 99.60% | Cost: 0.1199
# Epoch: 061 | Accuracy: 97.80% | Cost: 0.2847
# Epoch: 089 | Accuracy: 99.40% | Cost: 0.1917
# Epoch: 141 | Accuracy: 99.60% | Cost: 0.1114
# Epoch: 096 | Accuracy: 99.40% | Cost: 0.1735
# Epoch: 079 | Accuracy: 98.00% | Cost: 0.2288
# Epoch: 118 | Accuracy: 99.60% | Cost: 0.1429
# Epoch: 093 | Accuracy: 99.20% | Cost: 0.1750
# Epoch: 082 | Accuracy: 99.40% | Cost: 0.1902
# Epoch: 104 | Accuracy: 99.80% | Cost: 0.1433
# Epoch: 117 | Accuracy: 99.60% | Cost: 0.1249
# Epoch: 108 | Accuracy: 100.00% | Cost: 0.1340
# Epoch: 078 | Accuracy: 99.40% | Cost: 0.1895
# Epoch: 089 | Accuracy: 99.40% | Cost: 0.1905
# Epoch: 104 | Accuracy: 99.80% | Cost: 0.1469
# Epoch: 095 | Accuracy: 99.80% | Cost: 0.1674
# Epoch: 092 | Accuracy: 99.80% | Cost: 0.1759
# Epoch: 114 | Accuracy: 100.00% | Cost: 0.1235
# Epoch: 113 | Accuracy: 100.00% | Cost: 0.1287
# Epoch: 117 | Accuracy: 100.00% | Cost: 0.1250
# Epoch: 125 | Accuracy: 100.00% | Cost: 0.1160
# Epoch: 074 | Accuracy: 99.80% | Cost: 0.2069
# Epoch: 086 | Accuracy: 100.00% | Cost: 0.1633
# Epoch: 090 | Accuracy: 100.00% | Cost: 0.1672
# Epoch: 083 | Accuracy: 99.60% | Cost: 0.1824
# Epoch: 104 | Accuracy: 100.00% | Cost: 0.1322
# Epoch: 095 | Accuracy: 99.80% | Cost: 0.1551
# Epoch: 041 | Accuracy: 99.80% | Cost: 0.2895
# Epoch: 072 | Accuracy: 100.00% | Cost: 0.1839
# Epoch: 091 | Accuracy: 100.00% | Cost: 0.1422
# Epoch: 082 | Accuracy: 99.80% | Cost: 0.1579
# Epoch: 068 | Accuracy: 99.80% | Cost: 0.1895
# Epoch: 075 | Accuracy: 99.80% | Cost: 0.1772
# Epoch: 080 | Accuracy: 100.00% | Cost: 0.1619
# Epoch: 051 | Accuracy: 99.80% | Cost: 0.2508
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.1740
# Epoch: 078 | Accuracy: 100.00% | Cost: 0.1690
# Epoch: 042 | Accuracy: 99.80% | Cost: 0.2787
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.2022
# Epoch: 030 | Accuracy: 99.80% | Cost: 0.3567
# Epoch: 047 | Accuracy: 99.60% | Cost: 0.2573
# Epoch: 084 | Accuracy: 100.00% | Cost: 0.1435
# Epoch: 027 | Accuracy: 99.60% | Cost: 0.3956
# Epoch: 067 | Accuracy: 100.00% | Cost: 0.1834
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.2206
# Epoch: 071 | Accuracy: 100.00% | Cost: 0.1700
# Epoch: 046 | Accuracy: 99.80% | Cost: 0.2609
# Epoch: 304 | Accuracy: 91.20% | Cost: 0.2953
# Epoch: 358 | Accuracy: 92.40% | Cost: 0.2575
# Epoch: 329 | Accuracy: 92.40% | Cost: 0.2813
# Epoch: 281 | Accuracy: 94.00% | Cost: 0.2532
# Epoch: 036 | Accuracy: 65.60% | Cost: 0.6923
# Epoch: 337 | Accuracy: 92.20% | Cost: 0.2608
# Epoch: 293 | Accuracy: 92.40% | Cost: 0.2785
# Epoch: 392 | Accuracy: 93.80% | Cost: 0.2364
# Epoch: 334 | Accuracy: 91.80% | Cost: 0.2832
# Epoch: 281 | Accuracy: 91.80% | Cost: 0.2857
# Epoch: 359 | Accuracy: 99.20% | Cost: 0.0924
# Epoch: 258 | Accuracy: 98.20% | Cost: 0.1659
# Epoch: 329 | Accuracy: 99.00% | Cost: 0.1098
# Epoch: 294 | Accuracy: 97.20% | Cost: 0.1677
# Epoch: 351 | Accuracy: 98.00% | Cost: 0.1365
# Epoch: 306 | Accuracy: 98.40% | Cost: 0.1337
# Epoch: 256 | Accuracy: 96.20% | Cost: 0.1905
# Epoch: 342 | Accuracy: 99.00% | Cost: 0.0983
# Epoch: 254 | Accuracy: 97.60% | Cost: 0.1742
# Epoch: 227 | Accuracy: 98.40% | Cost: 0.1490
# Epoch: 256 | Accuracy: 99.60% | Cost: 0.1095
# Epoch: 260 | Accuracy: 98.80% | Cost: 0.1111
# Epoch: 299 | Accuracy: 98.40% | Cost: 0.1313
# Epoch: 211 | Accuracy: 98.80% | Cost: 0.1588
# Epoch: 201 | Accuracy: 96.40% | Cost: 0.1944
# Epoch: 276 | Accuracy: 96.80% | Cost: 0.1754
# Epoch: 353 | Accuracy: 99.20% | Cost: 0.0976
# Epoch: 302 | Accuracy: 99.60% | Cost: 0.0967
# Epoch: 290 | Accuracy: 96.00% | Cost: 0.2037
# Epoch: 261 | Accuracy: 98.40% | Cost: 0.1323
# Epoch: 159 | Accuracy: 97.60% | Cost: 0.1906
# Epoch: 227 | Accuracy: 99.60% | Cost: 0.1200
# Epoch: 231 | Accuracy: 99.40% | Cost: 0.1226
# Epoch: 243 | Accuracy: 99.00% | Cost: 0.1169
# Epoch: 266 | Accuracy: 99.00% | Cost: 0.1081
# Epoch: 134 | Accuracy: 97.80% | Cost: 0.2154
# Epoch: 156 | Accuracy: 97.20% | Cost: 0.2093
# Epoch: 231 | Accuracy: 99.20% | Cost: 0.1169
# Epoch: 191 | Accuracy: 99.20% | Cost: 0.1416
# Epoch: 209 | Accuracy: 99.60% | Cost: 0.1216
# Epoch: 140 | Accuracy: 98.40% | Cost: 0.1945
# Epoch: 175 | Accuracy: 98.80% | Cost: 0.1353
# Epoch: 217 | Accuracy: 99.40% | Cost: 0.1055
# Epoch: 164 | Accuracy: 97.60% | Cost: 0.1827
# Epoch: 137 | Accuracy: 98.80% | Cost: 0.1781
# Epoch: 199 | Accuracy: 99.20% | Cost: 0.1199
# Epoch: 187 | Accuracy: 99.20% | Cost: 0.1448
# Epoch: 206 | Accuracy: 99.20% | Cost: 0.1314
# Epoch: 240 | Accuracy: 99.40% | Cost: 0.0953
# Epoch: 195 | Accuracy: 99.40% | Cost: 0.1226
# Epoch: 187 | Accuracy: 99.60% | Cost: 0.1214
# Epoch: 198 | Accuracy: 100.00% | Cost: 0.1071
# Epoch: 146 | Accuracy: 98.40% | Cost: 0.2159
# Epoch: 197 | Accuracy: 99.80% | Cost: 0.0993
# Epoch: 174 | Accuracy: 99.20% | Cost: 0.1267
# Epoch: 161 | Accuracy: 99.40% | Cost: 0.1363
# Epoch: 160 | Accuracy: 98.80% | Cost: 0.1406
# Epoch: 184 | Accuracy: 99.20% | Cost: 0.1298
# Epoch: 183 | Accuracy: 99.60% | Cost: 0.1299
# Epoch: 198 | Accuracy: 99.80% | Cost: 0.1085
# Epoch: 179 | Accuracy: 100.00% | Cost: 0.0925
# Epoch: 097 | Accuracy: 98.20% | Cost: 0.2479
# Epoch: 159 | Accuracy: 99.40% | Cost: 0.1232
# Epoch: 130 | Accuracy: 99.60% | Cost: 0.1490
# Epoch: 157 | Accuracy: 99.80% | Cost: 0.1202
# Epoch: 135 | Accuracy: 99.40% | Cost: 0.1509
# Epoch: 171 | Accuracy: 100.00% | Cost: 0.1089
# Epoch: 150 | Accuracy: 99.40% | Cost: 0.1249
# Epoch: 161 | Accuracy: 99.60% | Cost: 0.1193
# Epoch: 170 | Accuracy: 100.00% | Cost: 0.1125
# Epoch: 116 | Accuracy: 99.40% | Cost: 0.1566
# Epoch: 158 | Accuracy: 99.60% | Cost: 0.1115
# Epoch: 159 | Accuracy: 99.80% | Cost: 0.1106
# Epoch: 163 | Accuracy: 100.00% | Cost: 0.1059
# Epoch: 100 | Accuracy: 99.00% | Cost: 0.1984
# Epoch: 155 | Accuracy: 99.80% | Cost: 0.1186
# Epoch: 150 | Accuracy: 99.80% | Cost: 0.1240
# Epoch: 097 | Accuracy: 98.40% | Cost: 0.2039
# Epoch: 161 | Accuracy: 99.80% | Cost: 0.1075
# Epoch: 130 | Accuracy: 99.00% | Cost: 0.1432
# Epoch: 161 | Accuracy: 100.00% | Cost: 0.0925
# Epoch: 131 | Accuracy: 100.00% | Cost: 0.1320
# Epoch: 104 | Accuracy: 99.60% | Cost: 0.1728
# Epoch: 117 | Accuracy: 100.00% | Cost: 0.1399
# Epoch: 109 | Accuracy: 99.40% | Cost: 0.1567
# Epoch: 153 | Accuracy: 100.00% | Cost: 0.1013
# Epoch: 140 | Accuracy: 99.80% | Cost: 0.1180
# Epoch: 096 | Accuracy: 99.80% | Cost: 0.1791
# Epoch: 109 | Accuracy: 99.80% | Cost: 0.1593
# Epoch: 088 | Accuracy: 99.00% | Cost: 0.2063
# Epoch: 125 | Accuracy: 99.80% | Cost: 0.1193
# Epoch: 083 | Accuracy: 99.40% | Cost: 0.1970
# Epoch: 124 | Accuracy: 100.00% | Cost: 0.1204
# Epoch: 108 | Accuracy: 100.00% | Cost: 0.1430
# Epoch: 090 | Accuracy: 99.60% | Cost: 0.1824
# Epoch: 092 | Accuracy: 99.40% | Cost: 0.1782
# Epoch: 096 | Accuracy: 99.60% | Cost: 0.1764
# Epoch: 066 | Accuracy: 98.60% | Cost: 0.2598
# Epoch: 113 | Accuracy: 100.00% | Cost: 0.1429
# Epoch: 112 | Accuracy: 99.80% | Cost: 0.1486
# Epoch: 067 | Accuracy: 99.80% | Cost: 0.1966
# Epoch: 033 | Accuracy: 99.40% | Cost: 0.3575
# Epoch: 032 | Accuracy: 99.20% | Cost: 0.3632
# Epoch: 059 | Accuracy: 99.20% | Cost: 0.2272
# Epoch: 063 | Accuracy: 99.20% | Cost: 0.2180
# Epoch: 045 | Accuracy: 99.20% | Cost: 0.3101
# Epoch: 065 | Accuracy: 99.80% | Cost: 0.2174
# Epoch: 079 | Accuracy: 99.80% | Cost: 0.1822
# Epoch: 076 | Accuracy: 99.60% | Cost: 0.1848
# Epoch: 065 | Accuracy: 99.60% | Cost: 0.2186
# Epoch: 029 | Accuracy: 99.60% | Cost: 0.3641
# Epoch: 033 | Accuracy: 99.40% | Cost: 0.3330
# Epoch: 038 | Accuracy: 99.80% | Cost: 0.3069
# Epoch: 039 | Accuracy: 99.80% | Cost: 0.3034
# Epoch: 031 | Accuracy: 99.60% | Cost: 0.3482
# Epoch: 042 | Accuracy: 99.60% | Cost: 0.2859
# Epoch: 033 | Accuracy: 99.40% | Cost: 0.3424
# Epoch: 038 | Accuracy: 99.60% | Cost: 0.3026
# Epoch: 073 | Accuracy: 99.80% | Cost: 0.1728
# Epoch: 047 | Accuracy: 99.80% | Cost: 0.2550
