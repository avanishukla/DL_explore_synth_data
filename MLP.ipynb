# %%
###install pytorch in colab
# !pip3 install https://download.pytorch.org/whl/cu100/torch-1.1.0-cp36-cp36m-linux_x86_64.whl
# !pip3 install https://download.pytorch.org/whl/cu100/torchvision-0.3.0-cp36-cp36m-linux_x86_64.whl

# %%
##mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
import numpy as np
import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import json
import os
import pandas as pd
import torch
import time
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.nn.init as init

# %%
base_path = '/content/drive/My Drive/DL_exp/'

# %%
### custom dataset class for dataset. read the csv in __init__ . 
# input : csv file path
# output: returns (data,label)
class load_dataset(Dataset):
    def __init__(self, data_path):
        self.samples = pd.read_csv(data_path).values

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        return self.samples[idx,:-1] ,self.samples[idx,-1]
      
### Multilayer Perceptron Model
# input : number of features (input), hidden nodes list , number of classes
class MultilayerPerceptron(torch.nn.Module):
  
    def __init__(self,num_features,hidden_nodes_list,num_classes):
        super(MultilayerPerceptron, self).__init__()
        
        num_hidden_layes = len(hidden_nodes_list)
        self.hidden = torch.nn.ModuleList()
        
        self.hidden.append(torch.nn.Linear(num_features, hidden_nodes_list[0]))
        for k in range(num_hidden_layes-1):
            self.hidden.append(torch.nn.Linear(hidden_nodes_list[k], hidden_nodes_list[k+1]))    
        self.hidden.append(torch.nn.Linear(hidden_nodes_list[num_hidden_layes-1], num_classes))
        
    # input : features
    # output: logits , probabilities
    def forward(self, x):
        out = x
        for layer in self.hidden[:-1]:
          out = layer(out)
          out = F.relu(out)

        logits = self.hidden[-1](out)
        probas = F.log_softmax(logits, dim=1)
        return logits, probas
      
### weight initialization function
# use : model.apply(init_weights)
def init_weights(m):
  if isinstance(m, torch.nn.Linear):
    if initialisation_method=='xavier':
      init.xavier_uniform_(m.weight)
    if initialisation_method=='he':
      init.kaiming_uniform_(m.weight)
    m.bias.data.fill_(0.01)
    
### function to compute the accuracy
# input : model, data of type DataLoader
# output: cost (log loss), accuracy 
def compute_accuracy(net, data_loader):
    net.eval()
    cost, correct_pred, num_examples = 0, 0, 0
    with torch.no_grad():
        for features, targets in data_loader:
            features = features.float().to(device)
            targets = targets.long().to(device)
            logits, probas = net(features)
            cost += F.cross_entropy(logits, targets) * targets.size(0)
            _, predicted_labels = torch.max(probas, 1)
            num_examples += targets.size(0)
            correct_pred += (predicted_labels == targets).sum()
        return cost/num_examples , correct_pred.float()/num_examples * 100

# %%
### Training of multiple models

# Input: csv file path contain sphere-shell d dimension features,label data. 
# Its name is like 'train_sp1_sh1.8_t1_2dim.csv' where sphere, shell radius, shell thickness and dimension are variable that have to specify.
radius_of_sphere_or_inner_shell = 1                  
radius_of_outer_shell = 2
thickness_of_shell = 0
dimentions = [2,4,8,16,32,64]          # list of dimention of the data
# data_dir = 'sphere_shell_data_version3_using_uniform/'
data_dir = 'shell_shell_data_version1/'
data_type = 'shell_shell'              # 'sphere_shell' or 'shell_shell'
# Output: upade 'result_file' file with  trained model details, accuracy, epoch and loss
# also update 'loss_file' file which have list of [{epoch},{loss}] data of trained model 
result_file = 'result/shell_shell_v1_result.json'
loss_file = 'result/loss_shell_shell_v1.json'


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
start_time = time.time()

if os.path.isfile(base_path+loss_file):
  with open(base_path+loss_file, mode='r') as readjson:
    try: 
      loss = json.loads(readjson.read())
    except ValueError: 
      loss = {} 
else:
      loss = {}
          
for dim in dimentions:
  if data_type=='sphere_shell':
    file_name = 'train_sp'+ str(radius_of_sphere_or_inner_shell) + '_sh'+ str(radius_of_outer_shell) + '_t' + str(thickness_of_shell)+ '_' + str(dim) + 'dim.csv'
  elif data_type=='shell_shell':
    file_name = 'train_in'+ str(radius_of_sphere_or_inner_shell) + '_out'+ str(radius_of_outer_shell) + '_t' + str(thickness_of_shell)+ '_' + str(dim) + 'dim.csv'

  csv_path = base_path+data_dir+file_name
  dataset = load_dataset(csv_path)
  size = len(dataset)
  train_dataloader = DataLoader(dataset, batch_size=size, shuffle=True)


  tmp_h = [2,4,6,8,12,16,24,32,48,64,128,256]             #list of total number of nodes in hidden layers
  tmp_i = [100,200,300,400,500,600,700,800,900,1000]      #list of random seed for weight initialization

  for t_h in tmp_h:
    for t_i in tmp_i:

      #architecture
      num_features  = next(iter(dataset))[0].shape[0]        # Input data dimention
      hidden_nodes_list   = [int(t_h/2),int(t_h/2)]                            # List of number of nodes at each hidden layer
      num_classes   = 2                                      # The number of output classes. In this case, 0 and 1
      
      # 'xavier' : Xavier Initialisation
      # 'he' : He Initialisation
      initialisation_method = 'xavier'
      
      # 'sgd' : SGD (lr) 
      # 'sgdwm' : SGD with Momentum (lr, momentum)
      # 'adagrad' : AdaGrad
      # 'adam' : Adam
      # 'ngd' : Natural gradient descent
      # 'l1' : L1 Regularisation
      # 'l2' : L2 Regularisation
      # 'pathnorm' : PathNorm Regularisation
      # 'spectralnorm' : Spectral norm Regularisation
      optimisation_method = 'sgdwm'  

      # Hyperparameters
      random_seed = t_i
      learning_rate = 0.05
            
      torch.manual_seed(random_seed)
      model = MultilayerPerceptron(num_features,hidden_nodes_list,num_classes)
      model.apply(init_weights)
      model = model.to(device)

      if optimisation_method=='sgd' or optimisation_method=='ngd':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
      if optimisation_method=='sgdwm':
        optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)
      if optimisation_method=='adagrad':
        optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate)
      if optimisation_method=='adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08)

      model_loss = []
      epoch = 0

      with torch.set_grad_enabled(False):
        cost,best_acc = compute_accuracy(model, train_dataloader)
      model_loss.append([epoch,cost.data.tolist(),best_acc.data.tolist()])
      
      count = 1
      prev_acc=best_acc
      best_epoch = epoch
      best_cost = cost

      while True:
          model.train()
          for batch_idx, (features, targets) in enumerate(train_dataloader):

              features = features.float().to(device)
              targets = targets.long().to(device)

              ### FORWARD AND BACK PROP
              logits, probas = model(features)
              cost = F.cross_entropy(logits, targets)
              optimizer.zero_grad()

              cost.backward()

              ### UPDATE MODEL PARAMETERS
              optimizer.step()


          with torch.set_grad_enabled(False):
              cost,acc = compute_accuracy(model, train_dataloader)
              
          epoch+=1
          model_loss.append([epoch,cost.data.tolist(),acc.data.tolist()])
          
          # Stopping conditions
          if prev_acc==acc:
            count+=1
          else:
            prev_acc=acc
            count=1
          # if (epoch>50 and best_acc-acc>=5) or count==20 or epoch==400:
          if (epoch>50 and best_acc-acc>=5) or epoch==400:
            break
          if acc>best_acc:
            best_acc=acc
            best_epoch = epoch
            best_cost = cost
 
      print('Epoch: %03d | Accuracy: %.2f%% | Cost: %.4f' % (best_epoch,best_acc,best_cost))
  
      if len(hidden_nodes_list)==1:
        loss.update({'sh'+ str(radius_of_outer_shell)+'dim'+str(dim)+'h'+str(t_h)+'i'+str(t_i):model_loss})
      else:
        loss.update({'sh'+ str(radius_of_outer_shell)+'dim'+str(dim)+'h'+str(t_h)+'i'+str(t_i)+'l2':model_loss})
    
      if os.path.isfile(base_path+result_file):
        with open(base_path+result_file, mode='r') as readjson:
          try: 
            result = json.loads(readjson.read())
          except ValueError: 
            result = []  
      else:
        result = []
       
      with open(base_path+result_file, mode='w') as feedjson:
        entry = {'sphere_radius': radius_of_sphere_or_inner_shell, 'shell_radius': radius_of_outer_shell, 'thickness' : thickness_of_shell, 'dimension':dim, 'n_nodes':hidden_nodes_list, 'random_seed':t_i, 'epoch':best_epoch, 'accuracy':best_acc.data.tolist(), 'cost':best_cost.data.tolist()}
        result.append(entry)
        json.dump(result, feedjson)

with open(base_path+loss_file, mode='w') as feedjson:
  json.dump(loss, feedjson)

print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 070 | Accuracy: 66.40% | Cost: 0.6030
# Epoch: 157 | Accuracy: 68.00% | Cost: 0.5650
# Epoch: 360 | Accuracy: 52.20% | Cost: 0.6927
# Epoch: 021 | Accuracy: 66.80% | Cost: 0.6910
# Epoch: 357 | Accuracy: 69.20% | Cost: 0.5495
# Epoch: 009 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 390 | Accuracy: 68.40% | Cost: 0.5667
# Epoch: 022 | Accuracy: 66.00% | Cost: 0.6367
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 008 | Accuracy: 63.60% | Cost: 0.6917
# Epoch: 074 | Accuracy: 77.60% | Cost: 0.5151
# Epoch: 083 | Accuracy: 66.60% | Cost: 0.5933
# Epoch: 091 | Accuracy: 86.80% | Cost: 0.3794
# Epoch: 108 | Accuracy: 67.00% | Cost: 0.5827
# Epoch: 069 | Accuracy: 81.40% | Cost: 0.5858
# Epoch: 152 | Accuracy: 83.80% | Cost: 0.4518
# Epoch: 069 | Accuracy: 67.00% | Cost: 0.6276
# Epoch: 144 | Accuracy: 67.60% | Cost: 0.5829
# Epoch: 075 | Accuracy: 86.60% | Cost: 0.3904
# Epoch: 006 | Accuracy: 52.20% | Cost: 0.6931
# Epoch: 385 | Accuracy: 85.60% | Cost: 0.3545
# Epoch: 031 | Accuracy: 70.20% | Cost: 0.6797
# Epoch: 092 | Accuracy: 82.40% | Cost: 0.4789
# Epoch: 147 | Accuracy: 100.00% | Cost: 0.0706
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.8621
# Epoch: 128 | Accuracy: 100.00% | Cost: 0.1629
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1959
# Epoch: 097 | Accuracy: 88.60% | Cost: 0.5027
# Epoch: 097 | Accuracy: 100.00% | Cost: 0.0772
# Epoch: 040 | Accuracy: 60.40% | Cost: 0.6922
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.1568
# Epoch: 060 | Accuracy: 100.00% | Cost: 0.2358
# Epoch: 109 | Accuracy: 100.00% | Cost: 0.1129
# Epoch: 053 | Accuracy: 100.00% | Cost: 0.1168
# Epoch: 047 | Accuracy: 100.00% | Cost: 0.2245
# Epoch: 048 | Accuracy: 66.20% | Cost: 0.6889
# Epoch: 188 | Accuracy: 100.00% | Cost: 0.0963
# Epoch: 071 | Accuracy: 100.00% | Cost: 0.1357
# Epoch: 073 | Accuracy: 100.00% | Cost: 0.0887
# Epoch: 058 | Accuracy: 100.00% | Cost: 0.1536
# Epoch: 036 | Accuracy: 100.00% | Cost: 0.4463
# Epoch: 050 | Accuracy: 100.00% | Cost: 0.2146
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.4477
# Epoch: 058 | Accuracy: 100.00% | Cost: 0.2298
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.4045
# Epoch: 041 | Accuracy: 100.00% | Cost: 0.4559
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.2977
# Epoch: 045 | Accuracy: 100.00% | Cost: 0.3071
# Epoch: 024 | Accuracy: 100.00% | Cost: 0.3908
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.2008
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1675
# Epoch: 067 | Accuracy: 100.00% | Cost: 0.2283
# Epoch: 085 | Accuracy: 100.00% | Cost: 0.1104
# Epoch: 058 | Accuracy: 100.00% | Cost: 0.1735
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.1897
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.3999
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.3240
# Epoch: 028 | Accuracy: 100.00% | Cost: 0.3696
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.1325
# Epoch: 050 | Accuracy: 100.00% | Cost: 0.2207
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.2477
# Epoch: 008 | Accuracy: 100.00% | Cost: 0.5745
# Epoch: 034 | Accuracy: 100.00% | Cost: 0.3956
# Epoch: 033 | Accuracy: 100.00% | Cost: 0.4255
# Epoch: 022 | Accuracy: 100.00% | Cost: 0.3243
# Epoch: 024 | Accuracy: 100.00% | Cost: 0.4431
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.2236
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.4309
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.2899
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.2579
# Epoch: 041 | Accuracy: 100.00% | Cost: 0.3905
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.3895
# Epoch: 029 | Accuracy: 100.00% | Cost: 0.3057
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.2515
# Epoch: 026 | Accuracy: 100.00% | Cost: 0.4221
# Epoch: 025 | Accuracy: 100.00% | Cost: 0.4413
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.4992
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.4975
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.4958
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.3299
# Epoch: 020 | Accuracy: 100.00% | Cost: 0.4127
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4696
# Epoch: 026 | Accuracy: 100.00% | Cost: 0.4809
# Epoch: 021 | Accuracy: 100.00% | Cost: 0.4560
# Epoch: 018 | Accuracy: 100.00% | Cost: 0.4575
# Epoch: 020 | Accuracy: 100.00% | Cost: 0.5052
# Epoch: 023 | Accuracy: 100.00% | Cost: 0.4433
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.4994
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.3572
# Epoch: 018 | Accuracy: 100.00% | Cost: 0.5177
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.4664
# Epoch: 012 | Accuracy: 100.00% | Cost: 0.5135
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.4393
# Epoch: 017 | Accuracy: 100.00% | Cost: 0.4688
# Epoch: 017 | Accuracy: 100.00% | Cost: 0.4752
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4626
# Epoch: 021 | Accuracy: 100.00% | Cost: 0.4957
# Epoch: 011 | Accuracy: 100.00% | Cost: 0.5517
# Epoch: 026 | Accuracy: 100.00% | Cost: 0.4902
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.4699
# Epoch: 017 | Accuracy: 100.00% | Cost: 0.5144
# Epoch: 020 | Accuracy: 100.00% | Cost: 0.4074
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4726
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4900
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4963
# Epoch: 015 | Accuracy: 100.00% | Cost: 0.4994
# Epoch: 015 | Accuracy: 100.00% | Cost: 0.4785
# Epoch: 017 | Accuracy: 100.00% | Cost: 0.5130
# Epoch: 014 | Accuracy: 100.00% | Cost: 0.5164
# Epoch: 021 | Accuracy: 100.00% | Cost: 0.4468
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4960
# Epoch: 015 | Accuracy: 100.00% | Cost: 0.5039
# Epoch: 017 | Accuracy: 100.00% | Cost: 0.5290
# Epoch: 017 | Accuracy: 100.00% | Cost: 0.5065
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4976
# Epoch: 015 | Accuracy: 100.00% | Cost: 0.5013
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4859
# Epoch: 018 | Accuracy: 100.00% | Cost: 0.4939
# Epoch: 016 | Accuracy: 100.00% | Cost: 0.4801
# Epoch: 015 | Accuracy: 100.00% | Cost: 0.5037
# Epoch: 376 | Accuracy: 64.20% | Cost: 0.5924
# Epoch: 398 | Accuracy: 58.20% | Cost: 0.6755
# Epoch: 303 | Accuracy: 64.20% | Cost: 0.6099
# Epoch: 006 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 072 | Accuracy: 59.60% | Cost: 0.6931
# Epoch: 006 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 250 | Accuracy: 65.40% | Cost: 0.5840
# Epoch: 125 | Accuracy: 64.00% | Cost: 0.6018
# Epoch: 361 | Accuracy: 64.60% | Cost: 0.6037
# Epoch: 128 | Accuracy: 68.60% | Cost: 0.5821
# Epoch: 321 | Accuracy: 85.40% | Cost: 0.3712
# Epoch: 231 | Accuracy: 79.00% | Cost: 0.4616
# Epoch: 296 | Accuracy: 81.00% | Cost: 0.4547
# Epoch: 236 | Accuracy: 64.00% | Cost: 0.6035
# Epoch: 383 | Accuracy: 82.80% | Cost: 0.4007
# Epoch: 272 | Accuracy: 68.20% | Cost: 0.5587
# Epoch: 182 | Accuracy: 76.00% | Cost: 0.4928
# Epoch: 385 | Accuracy: 77.40% | Cost: 0.4404
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.7056
# Epoch: 001 | Accuracy: 51.20% | Cost: 0.8977
# Epoch: 229 | Accuracy: 93.20% | Cost: 0.2106
# Epoch: 001 | Accuracy: 51.60% | Cost: 0.8373
# Epoch: 362 | Accuracy: 93.20% | Cost: 0.2226
# Epoch: 353 | Accuracy: 89.00% | Cost: 0.2757
# Epoch: 287 | Accuracy: 95.00% | Cost: 0.1793
# Epoch: 397 | Accuracy: 87.00% | Cost: 0.3230
# Epoch: 347 | Accuracy: 90.00% | Cost: 0.2776
# Epoch: 398 | Accuracy: 90.80% | Cost: 0.2808
# Epoch: 195 | Accuracy: 90.80% | Cost: 0.2936
# Epoch: 148 | Accuracy: 93.40% | Cost: 0.2040
# Epoch: 255 | Accuracy: 99.60% | Cost: 0.0428
# Epoch: 295 | Accuracy: 99.60% | Cost: 0.0467
# Epoch: 300 | Accuracy: 98.20% | Cost: 0.0973
# Epoch: 326 | Accuracy: 98.80% | Cost: 0.0732
# Epoch: 305 | Accuracy: 94.40% | Cost: 0.1725
# Epoch: 319 | Accuracy: 99.60% | Cost: 0.0421
# Epoch: 249 | Accuracy: 97.60% | Cost: 0.0943
# Epoch: 396 | Accuracy: 98.40% | Cost: 0.0871
# Epoch: 312 | Accuracy: 97.40% | Cost: 0.0982
# Epoch: 285 | Accuracy: 98.80% | Cost: 0.0589
# Epoch: 118 | Accuracy: 100.00% | Cost: 0.0208
# Epoch: 105 | Accuracy: 100.00% | Cost: 0.0422
# Epoch: 121 | Accuracy: 100.00% | Cost: 0.0435
# Epoch: 130 | Accuracy: 100.00% | Cost: 0.0333
# Epoch: 097 | Accuracy: 100.00% | Cost: 0.0248
# Epoch: 110 | Accuracy: 100.00% | Cost: 0.0838
# Epoch: 078 | Accuracy: 100.00% | Cost: 0.0568
# Epoch: 181 | Accuracy: 100.00% | Cost: 0.0347
# Epoch: 167 | Accuracy: 100.00% | Cost: 0.0336
# Epoch: 112 | Accuracy: 100.00% | Cost: 0.0344
# Epoch: 068 | Accuracy: 100.00% | Cost: 0.0823
# Epoch: 091 | Accuracy: 100.00% | Cost: 0.0505
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.0686
# Epoch: 154 | Accuracy: 100.00% | Cost: 0.0263
# Epoch: 074 | Accuracy: 100.00% | Cost: 0.0658
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1314
# Epoch: 062 | Accuracy: 100.00% | Cost: 0.1280
# Epoch: 080 | Accuracy: 100.00% | Cost: 0.0710
# Epoch: 110 | Accuracy: 100.00% | Cost: 0.0452
# Epoch: 140 | Accuracy: 100.00% | Cost: 0.0245
# Epoch: 083 | Accuracy: 100.00% | Cost: 0.0568
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.1756
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.0799
# Epoch: 045 | Accuracy: 100.00% | Cost: 0.1736
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.0630
# Epoch: 062 | Accuracy: 100.00% | Cost: 0.0472
# Epoch: 053 | Accuracy: 100.00% | Cost: 0.0911
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.0858
# Epoch: 063 | Accuracy: 100.00% | Cost: 0.0844
# Epoch: 045 | Accuracy: 100.00% | Cost: 0.1775
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.2576
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.0946
# Epoch: 048 | Accuracy: 100.00% | Cost: 0.2221
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.2023
# Epoch: 044 | Accuracy: 100.00% | Cost: 0.1696
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.1768
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.2307
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1014
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.2691
# Epoch: 080 | Accuracy: 100.00% | Cost: 0.0527
# Epoch: 024 | Accuracy: 100.00% | Cost: 0.4391
# Epoch: 041 | Accuracy: 100.00% | Cost: 0.1648
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1765
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.1630
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.0574
# Epoch: 056 | Accuracy: 100.00% | Cost: 0.0823
# Epoch: 026 | Accuracy: 100.00% | Cost: 0.3511
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.2966
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.0741
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.2433
# Epoch: 030 | Accuracy: 100.00% | Cost: 0.3391
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.3469
# Epoch: 036 | Accuracy: 100.00% | Cost: 0.2330
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.2652
# Epoch: 030 | Accuracy: 100.00% | Cost: 0.3271
# Epoch: 046 | Accuracy: 100.00% | Cost: 0.1795
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.2327
# Epoch: 028 | Accuracy: 100.00% | Cost: 0.2867
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.1754
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.2937
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.2794
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.3389
# Epoch: 032 | Accuracy: 100.00% | Cost: 0.3027
# Epoch: 029 | Accuracy: 100.00% | Cost: 0.3744
# Epoch: 034 | Accuracy: 100.00% | Cost: 0.2042
# Epoch: 025 | Accuracy: 100.00% | Cost: 0.3457
# Epoch: 021 | Accuracy: 100.00% | Cost: 0.4782
# Epoch: 029 | Accuracy: 100.00% | Cost: 0.3410
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.3335
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.2099
# Epoch: 024 | Accuracy: 100.00% | Cost: 0.3786
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.3116
# Epoch: 030 | Accuracy: 100.00% | Cost: 0.2978
# Epoch: 028 | Accuracy: 100.00% | Cost: 0.3203
# Epoch: 019 | Accuracy: 100.00% | Cost: 0.4932
# Epoch: 026 | Accuracy: 100.00% | Cost: 0.3739
# Epoch: 023 | Accuracy: 100.00% | Cost: 0.3704
# Epoch: 018 | Accuracy: 100.00% | Cost: 0.5090
# Epoch: 018 | Accuracy: 100.00% | Cost: 0.5274
# Epoch: 022 | Accuracy: 100.00% | Cost: 0.3661
# Epoch: 232 | Accuracy: 61.80% | Cost: 0.6238
# Epoch: 006 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.8413
# Epoch: 007 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 334 | Accuracy: 64.20% | Cost: 0.6032
# Epoch: 008 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 326 | Accuracy: 63.00% | Cost: 0.6136
# Epoch: 272 | Accuracy: 65.20% | Cost: 0.6019
# Epoch: 177 | Accuracy: 65.20% | Cost: 0.6302
# Epoch: 014 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 049 | Accuracy: 63.20% | Cost: 0.6868
# Epoch: 302 | Accuracy: 80.40% | Cost: 0.4502
# Epoch: 390 | Accuracy: 77.20% | Cost: 0.4699
# Epoch: 370 | Accuracy: 58.40% | Cost: 0.6740
# Epoch: 157 | Accuracy: 76.00% | Cost: 0.4919
# Epoch: 295 | Accuracy: 75.80% | Cost: 0.5058
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.6937
# Epoch: 391 | Accuracy: 76.20% | Cost: 0.4913
# Epoch: 399 | Accuracy: 77.20% | Cost: 0.4763
# Epoch: 205 | Accuracy: 65.60% | Cost: 0.5897
# Epoch: 394 | Accuracy: 87.20% | Cost: 0.3247
# Epoch: 304 | Accuracy: 88.20% | Cost: 0.2918
# Epoch: 216 | Accuracy: 85.80% | Cost: 0.3691
# Epoch: 218 | Accuracy: 85.80% | Cost: 0.3374
# Epoch: 206 | Accuracy: 86.00% | Cost: 0.3470
# Epoch: 260 | Accuracy: 86.80% | Cost: 0.3309
# Epoch: 044 | Accuracy: 63.60% | Cost: 0.6914
# Epoch: 344 | Accuracy: 89.20% | Cost: 0.2833
# Epoch: 296 | Accuracy: 85.80% | Cost: 0.3526
# Epoch: 296 | Accuracy: 88.20% | Cost: 0.3185
# Epoch: 336 | Accuracy: 95.60% | Cost: 0.1649
# Epoch: 320 | Accuracy: 89.20% | Cost: 0.2983
# Epoch: 289 | Accuracy: 95.40% | Cost: 0.1627
# Epoch: 383 | Accuracy: 92.60% | Cost: 0.1939
# Epoch: 392 | Accuracy: 95.60% | Cost: 0.1380
# Epoch: 335 | Accuracy: 96.40% | Cost: 0.1345
# Epoch: 374 | Accuracy: 90.20% | Cost: 0.2747
# Epoch: 390 | Accuracy: 88.60% | Cost: 0.3073
# Epoch: 397 | Accuracy: 96.80% | Cost: 0.1299
# Epoch: 198 | Accuracy: 91.00% | Cost: 0.2564
# Epoch: 290 | Accuracy: 99.60% | Cost: 0.0431
# Epoch: 327 | Accuracy: 100.00% | Cost: 0.0301
# Epoch: 271 | Accuracy: 99.80% | Cost: 0.0380
# Epoch: 251 | Accuracy: 99.80% | Cost: 0.0377
# Epoch: 133 | Accuracy: 100.00% | Cost: 0.0402
# Epoch: 387 | Accuracy: 99.60% | Cost: 0.0361
# Epoch: 293 | Accuracy: 99.80% | Cost: 0.0408
# Epoch: 229 | Accuracy: 100.00% | Cost: 0.0283
# Epoch: 283 | Accuracy: 100.00% | Cost: 0.0235
# Epoch: 307 | Accuracy: 100.00% | Cost: 0.0320
# Epoch: 142 | Accuracy: 100.00% | Cost: 0.0266
# Epoch: 140 | Accuracy: 100.00% | Cost: 0.0292
# Epoch: 161 | Accuracy: 100.00% | Cost: 0.0255
# Epoch: 105 | Accuracy: 100.00% | Cost: 0.0520
# Epoch: 131 | Accuracy: 100.00% | Cost: 0.0322
# Epoch: 213 | Accuracy: 100.00% | Cost: 0.0187
# Epoch: 175 | Accuracy: 100.00% | Cost: 0.0238
# Epoch: 157 | Accuracy: 100.00% | Cost: 0.0344
# Epoch: 120 | Accuracy: 100.00% | Cost: 0.0314
# Epoch: 110 | Accuracy: 100.00% | Cost: 0.0397
# Epoch: 134 | Accuracy: 100.00% | Cost: 0.0503
# Epoch: 150 | Accuracy: 100.00% | Cost: 0.0324
# Epoch: 105 | Accuracy: 100.00% | Cost: 0.0628
# Epoch: 095 | Accuracy: 100.00% | Cost: 0.0418
# Epoch: 115 | Accuracy: 100.00% | Cost: 0.0427
# Epoch: 096 | Accuracy: 100.00% | Cost: 0.0492
# Epoch: 095 | Accuracy: 100.00% | Cost: 0.0416
# Epoch: 108 | Accuracy: 100.00% | Cost: 0.0271
# Epoch: 102 | Accuracy: 100.00% | Cost: 0.0465
# Epoch: 136 | Accuracy: 100.00% | Cost: 0.0238
# Epoch: 078 | Accuracy: 100.00% | Cost: 0.0360
# Epoch: 084 | Accuracy: 100.00% | Cost: 0.0395
# Epoch: 092 | Accuracy: 100.00% | Cost: 0.0449
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.0756
# Epoch: 084 | Accuracy: 100.00% | Cost: 0.0316
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.0539
# Epoch: 088 | Accuracy: 100.00% | Cost: 0.0629
# Epoch: 087 | Accuracy: 100.00% | Cost: 0.0397
# Epoch: 084 | Accuracy: 100.00% | Cost: 0.0501
# Epoch: 061 | Accuracy: 100.00% | Cost: 0.0847
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.1280
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.0988
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.0506
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.0889
# Epoch: 063 | Accuracy: 100.00% | Cost: 0.0466
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.2833
# Epoch: 061 | Accuracy: 100.00% | Cost: 0.0644
# Epoch: 065 | Accuracy: 100.00% | Cost: 0.0506
# Epoch: 062 | Accuracy: 100.00% | Cost: 0.0673
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.0984
# Epoch: 062 | Accuracy: 100.00% | Cost: 0.0780
# Epoch: 045 | Accuracy: 100.00% | Cost: 0.1630
# Epoch: 060 | Accuracy: 100.00% | Cost: 0.0815
# Epoch: 053 | Accuracy: 100.00% | Cost: 0.1747
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.1104
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.0939
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.0559
# Epoch: 081 | Accuracy: 100.00% | Cost: 0.0357
# Epoch: 036 | Accuracy: 100.00% | Cost: 0.1863
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.0510
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.3066
# Epoch: 023 | Accuracy: 100.00% | Cost: 0.4242
# Epoch: 034 | Accuracy: 100.00% | Cost: 0.3017
# Epoch: 036 | Accuracy: 100.00% | Cost: 0.2882
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1551
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.1952
# Epoch: 034 | Accuracy: 100.00% | Cost: 0.2300
# Epoch: 041 | Accuracy: 100.00% | Cost: 0.1560
# Epoch: 044 | Accuracy: 100.00% | Cost: 0.1699
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.0686
# Epoch: 024 | Accuracy: 100.00% | Cost: 0.4030
# Epoch: 028 | Accuracy: 100.00% | Cost: 0.2990
# Epoch: 020 | Accuracy: 100.00% | Cost: 0.4765
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.1831
# Epoch: 020 | Accuracy: 100.00% | Cost: 0.4322
# Epoch: 024 | Accuracy: 100.00% | Cost: 0.3673
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.2220
# Epoch: 031 | Accuracy: 100.00% | Cost: 0.2978
# Epoch: 025 | Accuracy: 100.00% | Cost: 0.3545
# Epoch: 027 | Accuracy: 100.00% | Cost: 0.2956
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.8470
# Epoch: 076 | Accuracy: 67.60% | Cost: 0.6038
# Epoch: 291 | Accuracy: 67.20% | Cost: 0.6024
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.6975
# Epoch: 311 | Accuracy: 66.20% | Cost: 0.6090
# Epoch: 284 | Accuracy: 65.20% | Cost: 0.6134
# Epoch: 002 | Accuracy: 54.00% | Cost: 0.7307
# Epoch: 118 | Accuracy: 67.00% | Cost: 0.6048
# Epoch: 353 | Accuracy: 69.20% | Cost: 0.5615
# Epoch: 003 | Accuracy: 51.20% | Cost: 0.7091
# Epoch: 399 | Accuracy: 81.60% | Cost: 0.4438
# Epoch: 378 | Accuracy: 80.40% | Cost: 0.4526
# Epoch: 388 | Accuracy: 68.20% | Cost: 0.5715
# Epoch: 293 | Accuracy: 78.60% | Cost: 0.4843
# Epoch: 344 | Accuracy: 66.00% | Cost: 0.6029
# Epoch: 390 | Accuracy: 83.80% | Cost: 0.4050
# Epoch: 356 | Accuracy: 80.00% | Cost: 0.4550
# Epoch: 399 | Accuracy: 63.60% | Cost: 0.6033
# Epoch: 382 | Accuracy: 60.60% | Cost: 0.6390
# Epoch: 246 | Accuracy: 79.20% | Cost: 0.4735
# Epoch: 397 | Accuracy: 87.80% | Cost: 0.3483
# Epoch: 333 | Accuracy: 89.40% | Cost: 0.2995
# Epoch: 353 | Accuracy: 90.60% | Cost: 0.2713
# Epoch: 363 | Accuracy: 92.40% | Cost: 0.2525
# Epoch: 294 | Accuracy: 89.60% | Cost: 0.2827
# Epoch: 219 | Accuracy: 88.80% | Cost: 0.3176
# Epoch: 002 | Accuracy: 51.00% | Cost: 0.7231
# Epoch: 330 | Accuracy: 88.20% | Cost: 0.3198
# Epoch: 329 | Accuracy: 88.40% | Cost: 0.3019
# Epoch: 353 | Accuracy: 91.80% | Cost: 0.2598
# Epoch: 397 | Accuracy: 95.00% | Cost: 0.1776
# Epoch: 392 | Accuracy: 94.20% | Cost: 0.1873
# Epoch: 347 | Accuracy: 96.80% | Cost: 0.1297
# Epoch: 399 | Accuracy: 94.40% | Cost: 0.1704
# Epoch: 376 | Accuracy: 96.20% | Cost: 0.1675
# Epoch: 383 | Accuracy: 95.40% | Cost: 0.1700
# Epoch: 383 | Accuracy: 95.00% | Cost: 0.1685
# Epoch: 317 | Accuracy: 96.20% | Cost: 0.0947
# Epoch: 385 | Accuracy: 94.80% | Cost: 0.1893
# Epoch: 383 | Accuracy: 93.80% | Cost: 0.2133
# Epoch: 226 | Accuracy: 100.00% | Cost: 0.0342
# Epoch: 373 | Accuracy: 100.00% | Cost: 0.0248
# Epoch: 294 | Accuracy: 99.40% | Cost: 0.0513
# Epoch: 385 | Accuracy: 99.80% | Cost: 0.0253
# Epoch: 221 | Accuracy: 100.00% | Cost: 0.0309
# Epoch: 338 | Accuracy: 99.20% | Cost: 0.0478
# Epoch: 164 | Accuracy: 100.00% | Cost: 0.0439
# Epoch: 276 | Accuracy: 100.00% | Cost: 0.0236
# Epoch: 292 | Accuracy: 99.80% | Cost: 0.0372
# Epoch: 169 | Accuracy: 100.00% | Cost: 0.0337
# Epoch: 216 | Accuracy: 100.00% | Cost: 0.0396
# Epoch: 246 | Accuracy: 100.00% | Cost: 0.0199
# Epoch: 168 | Accuracy: 100.00% | Cost: 0.0379
# Epoch: 182 | Accuracy: 99.60% | Cost: 0.0607
# Epoch: 173 | Accuracy: 100.00% | Cost: 0.0526
# Epoch: 158 | Accuracy: 100.00% | Cost: 0.0449
# Epoch: 133 | Accuracy: 100.00% | Cost: 0.0391
# Epoch: 157 | Accuracy: 100.00% | Cost: 0.0427
# Epoch: 137 | Accuracy: 100.00% | Cost: 0.0399
# Epoch: 173 | Accuracy: 99.80% | Cost: 0.0471
# Epoch: 110 | Accuracy: 100.00% | Cost: 0.0342
# Epoch: 093 | Accuracy: 100.00% | Cost: 0.0500
# Epoch: 129 | Accuracy: 100.00% | Cost: 0.0380
# Epoch: 105 | Accuracy: 100.00% | Cost: 0.0389
# Epoch: 121 | Accuracy: 100.00% | Cost: 0.0672
# Epoch: 111 | Accuracy: 100.00% | Cost: 0.0653
# Epoch: 117 | Accuracy: 100.00% | Cost: 0.0377
# Epoch: 108 | Accuracy: 100.00% | Cost: 0.0504
# Epoch: 123 | Accuracy: 100.00% | Cost: 0.0337
# Epoch: 107 | Accuracy: 100.00% | Cost: 0.0527
# Epoch: 093 | Accuracy: 100.00% | Cost: 0.0736
# Epoch: 073 | Accuracy: 100.00% | Cost: 0.0710
# Epoch: 088 | Accuracy: 100.00% | Cost: 0.0581
# Epoch: 094 | Accuracy: 100.00% | Cost: 0.0521
# Epoch: 090 | Accuracy: 100.00% | Cost: 0.0691
# Epoch: 119 | Accuracy: 100.00% | Cost: 0.0472
# Epoch: 087 | Accuracy: 100.00% | Cost: 0.0631
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.0804
# Epoch: 093 | Accuracy: 100.00% | Cost: 0.0421
# Epoch: 096 | Accuracy: 100.00% | Cost: 0.0352
# Epoch: 079 | Accuracy: 100.00% | Cost: 0.0616
# Epoch: 091 | Accuracy: 100.00% | Cost: 0.0365
# Epoch: 070 | Accuracy: 100.00% | Cost: 0.0671
# Epoch: 072 | Accuracy: 100.00% | Cost: 0.0535
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0574
# Epoch: 066 | Accuracy: 100.00% | Cost: 0.0544
# Epoch: 067 | Accuracy: 100.00% | Cost: 0.0943
# Epoch: 086 | Accuracy: 100.00% | Cost: 0.0335
# Epoch: 074 | Accuracy: 100.00% | Cost: 0.0893
# Epoch: 078 | Accuracy: 100.00% | Cost: 0.0448
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0485
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.0885
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.1368
# Epoch: 072 | Accuracy: 100.00% | Cost: 0.0664
# Epoch: 074 | Accuracy: 100.00% | Cost: 0.0472
# Epoch: 068 | Accuracy: 100.00% | Cost: 0.0855
# Epoch: 071 | Accuracy: 100.00% | Cost: 0.0462
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.1029
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0508
# Epoch: 072 | Accuracy: 100.00% | Cost: 0.0590
# Epoch: 044 | Accuracy: 100.00% | Cost: 0.1713
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.0757
# Epoch: 050 | Accuracy: 100.00% | Cost: 0.1078
# Epoch: 046 | Accuracy: 100.00% | Cost: 0.1864
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1352
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1611
# Epoch: 048 | Accuracy: 100.00% | Cost: 0.1804
# Epoch: 051 | Accuracy: 100.00% | Cost: 0.1266
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.0762
# Epoch: 037 | Accuracy: 100.00% | Cost: 0.2286
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.1546
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1324
# Epoch: 036 | Accuracy: 100.00% | Cost: 0.1863
# Epoch: 033 | Accuracy: 100.00% | Cost: 0.2914
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1678
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.1818
# Epoch: 038 | Accuracy: 100.00% | Cost: 0.1857
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1147
# Epoch: 028 | Accuracy: 100.00% | Cost: 0.3219
# Epoch: 036 | Accuracy: 100.00% | Cost: 0.1712
# Epoch: 276 | Accuracy: 70.00% | Cost: 0.5633
# Epoch: 223 | Accuracy: 72.00% | Cost: 0.5559
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.6974
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.6935
# Epoch: 393 | Accuracy: 71.80% | Cost: 0.5548
# Epoch: 399 | Accuracy: 67.40% | Cost: 0.5981
# Epoch: 204 | Accuracy: 71.20% | Cost: 0.5735
# Epoch: 314 | Accuracy: 70.20% | Cost: 0.5671
# Epoch: 151 | Accuracy: 70.80% | Cost: 0.5514
# Epoch: 304 | Accuracy: 71.60% | Cost: 0.5592
# Epoch: 347 | Accuracy: 89.60% | Cost: 0.3236
# Epoch: 300 | Accuracy: 86.00% | Cost: 0.3653
# Epoch: 397 | Accuracy: 84.80% | Cost: 0.3725
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.7202
# Epoch: 352 | Accuracy: 69.20% | Cost: 0.5715
# Epoch: 344 | Accuracy: 83.20% | Cost: 0.4056
# Epoch: 358 | Accuracy: 84.20% | Cost: 0.3981
# Epoch: 364 | Accuracy: 81.80% | Cost: 0.4341
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.7744
# Epoch: 360 | Accuracy: 85.80% | Cost: 0.3827
# Epoch: 399 | Accuracy: 84.40% | Cost: 0.3750
# Epoch: 385 | Accuracy: 68.60% | Cost: 0.5682
# Epoch: 396 | Accuracy: 93.80% | Cost: 0.2317
# Epoch: 396 | Accuracy: 90.00% | Cost: 0.2825
# Epoch: 399 | Accuracy: 92.80% | Cost: 0.2380
# Epoch: 398 | Accuracy: 92.60% | Cost: 0.2408
# Epoch: 346 | Accuracy: 93.00% | Cost: 0.2472
# Epoch: 359 | Accuracy: 96.00% | Cost: 0.1786
# Epoch: 399 | Accuracy: 83.20% | Cost: 0.4122
# Epoch: 328 | Accuracy: 95.40% | Cost: 0.1827
# Epoch: 395 | Accuracy: 99.40% | Cost: 0.0514
# Epoch: 342 | Accuracy: 100.00% | Cost: 0.0162
# Epoch: 350 | Accuracy: 99.40% | Cost: 0.0818
# Epoch: 393 | Accuracy: 100.00% | Cost: 0.0309
# Epoch: 393 | Accuracy: 98.00% | Cost: 0.1006
# Epoch: 355 | Accuracy: 100.00% | Cost: 0.0270
# Epoch: 398 | Accuracy: 87.80% | Cost: 0.3290
# Epoch: 262 | Accuracy: 99.20% | Cost: 0.0696
# Epoch: 397 | Accuracy: 98.60% | Cost: 0.0798
# Epoch: 346 | Accuracy: 99.00% | Cost: 0.0833
# Epoch: 217 | Accuracy: 100.00% | Cost: 0.0405
# Epoch: 214 | Accuracy: 100.00% | Cost: 0.0278
# Epoch: 193 | Accuracy: 100.00% | Cost: 0.0342
# Epoch: 282 | Accuracy: 99.80% | Cost: 0.0262
# Epoch: 255 | Accuracy: 99.40% | Cost: 0.0535
# Epoch: 245 | Accuracy: 100.00% | Cost: 0.0707
# Epoch: 202 | Accuracy: 99.80% | Cost: 0.0565
# Epoch: 308 | Accuracy: 99.80% | Cost: 0.0397
# Epoch: 178 | Accuracy: 100.00% | Cost: 0.0300
# Epoch: 167 | Accuracy: 100.00% | Cost: 0.0411
# Epoch: 291 | Accuracy: 100.00% | Cost: 0.0226
# Epoch: 133 | Accuracy: 100.00% | Cost: 0.0344
# Epoch: 179 | Accuracy: 100.00% | Cost: 0.0286
# Epoch: 147 | Accuracy: 100.00% | Cost: 0.0439
# Epoch: 163 | Accuracy: 100.00% | Cost: 0.0434
# Epoch: 174 | Accuracy: 100.00% | Cost: 0.0598
# Epoch: 192 | Accuracy: 100.00% | Cost: 0.0247
# Epoch: 217 | Accuracy: 100.00% | Cost: 0.0163
# Epoch: 182 | Accuracy: 100.00% | Cost: 0.0468
# Epoch: 187 | Accuracy: 100.00% | Cost: 0.0306
# Epoch: 106 | Accuracy: 100.00% | Cost: 0.0643
# Epoch: 290 | Accuracy: 100.00% | Cost: 0.0165
# Epoch: 109 | Accuracy: 100.00% | Cost: 0.0536
# Epoch: 096 | Accuracy: 100.00% | Cost: 0.0601
# Epoch: 111 | Accuracy: 100.00% | Cost: 0.0472
# Epoch: 131 | Accuracy: 100.00% | Cost: 0.0311
# Epoch: 114 | Accuracy: 100.00% | Cost: 0.0685
# Epoch: 165 | Accuracy: 100.00% | Cost: 0.0295
# Epoch: 138 | Accuracy: 100.00% | Cost: 0.0333
# Epoch: 102 | Accuracy: 100.00% | Cost: 0.0550
# Epoch: 098 | Accuracy: 100.00% | Cost: 0.0496
# Epoch: 081 | Accuracy: 100.00% | Cost: 0.1072
# Epoch: 110 | Accuracy: 100.00% | Cost: 0.0358
# Epoch: 118 | Accuracy: 100.00% | Cost: 0.0295
# Epoch: 118 | Accuracy: 100.00% | Cost: 0.0358
# Epoch: 095 | Accuracy: 100.00% | Cost: 0.0471
# Epoch: 095 | Accuracy: 100.00% | Cost: 0.0559
# Epoch: 098 | Accuracy: 100.00% | Cost: 0.0413
# Epoch: 098 | Accuracy: 100.00% | Cost: 0.0464
# Epoch: 096 | Accuracy: 100.00% | Cost: 0.0499
# Epoch: 084 | Accuracy: 100.00% | Cost: 0.0914
# Epoch: 081 | Accuracy: 100.00% | Cost: 0.0901
# Epoch: 069 | Accuracy: 100.00% | Cost: 0.0860
# Epoch: 080 | Accuracy: 100.00% | Cost: 0.0730
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0735
# Epoch: 080 | Accuracy: 100.00% | Cost: 0.0706
# Epoch: 089 | Accuracy: 100.00% | Cost: 0.0617
# Epoch: 080 | Accuracy: 100.00% | Cost: 0.0703
# Epoch: 098 | Accuracy: 100.00% | Cost: 0.0515
# Epoch: 081 | Accuracy: 100.00% | Cost: 0.0621
# Epoch: 072 | Accuracy: 100.00% | Cost: 0.0645
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0802
# Epoch: 074 | Accuracy: 100.00% | Cost: 0.0631
# Epoch: 083 | Accuracy: 100.00% | Cost: 0.0373
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0690
# Epoch: 063 | Accuracy: 100.00% | Cost: 0.0628
# Epoch: 071 | Accuracy: 100.00% | Cost: 0.0804
# Epoch: 083 | Accuracy: 100.00% | Cost: 0.0618
# Epoch: 065 | Accuracy: 100.00% | Cost: 0.0805
# Epoch: 074 | Accuracy: 100.00% | Cost: 0.0538
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.1100
# Epoch: 050 | Accuracy: 100.00% | Cost: 0.1458
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.1016
# Epoch: 056 | Accuracy: 100.00% | Cost: 0.0658
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.1122
# Epoch: 052 | Accuracy: 100.00% | Cost: 0.1225
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.0839
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.0746
# Epoch: 059 | Accuracy: 100.00% | Cost: 0.0961
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.1024
# Epoch: 030 | Accuracy: 100.00% | Cost: 0.3350
# Epoch: 040 | Accuracy: 100.00% | Cost: 0.1858
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.2082
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.1215
# Epoch: 042 | Accuracy: 100.00% | Cost: 0.1614
# Epoch: 050 | Accuracy: 100.00% | Cost: 0.1256
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.2004
# Epoch: 020 | Accuracy: 100.00% | Cost: 0.5054
# Epoch: 039 | Accuracy: 100.00% | Cost: 0.1688
# Epoch: 044 | Accuracy: 100.00% | Cost: 0.1253
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.7540
# Epoch: 376 | Accuracy: 75.40% | Cost: 0.5130
# Epoch: 396 | Accuracy: 71.00% | Cost: 0.5430
# Epoch: 388 | Accuracy: 73.00% | Cost: 0.5246
# Epoch: 002 | Accuracy: 50.20% | Cost: 0.7215
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.6932
# Epoch: 386 | Accuracy: 73.60% | Cost: 0.5203
# Epoch: 395 | Accuracy: 67.00% | Cost: 0.5935
# Epoch: 368 | Accuracy: 72.40% | Cost: 0.5335
# Epoch: 374 | Accuracy: 74.60% | Cost: 0.5271
# Epoch: 358 | Accuracy: 92.60% | Cost: 0.2522
# Epoch: 378 | Accuracy: 91.00% | Cost: 0.2703
# Epoch: 391 | Accuracy: 93.00% | Cost: 0.2542
# Epoch: 394 | Accuracy: 74.00% | Cost: 0.5189
# Epoch: 366 | Accuracy: 90.00% | Cost: 0.2887
# Epoch: 302 | Accuracy: 91.40% | Cost: 0.2897
# Epoch: 392 | Accuracy: 90.00% | Cost: 0.3220
# Epoch: 388 | Accuracy: 95.40% | Cost: 0.1633
# Epoch: 364 | Accuracy: 91.00% | Cost: 0.2707
# Epoch: 377 | Accuracy: 93.00% | Cost: 0.2207
# Epoch: 399 | Accuracy: 98.40% | Cost: 0.0672
# Epoch: 174 | Accuracy: 94.60% | Cost: 0.2084
# Epoch: 000 | Accuracy: 50.00% | Cost: 0.7553
# Epoch: 048 | Accuracy: 61.60% | Cost: 0.6928
# Epoch: 294 | Accuracy: 99.00% | Cost: 0.0816
# Epoch: 390 | Accuracy: 90.40% | Cost: 0.2832
# Epoch: 397 | Accuracy: 91.60% | Cost: 0.2690
# Epoch: 393 | Accuracy: 95.00% | Cost: 0.1881
# Epoch: 374 | Accuracy: 86.20% | Cost: 0.3737
# Epoch: 350 | Accuracy: 97.60% | Cost: 0.1350
# Epoch: 299 | Accuracy: 98.60% | Cost: 0.0931
# Epoch: 192 | Accuracy: 99.40% | Cost: 0.0679
# Epoch: 333 | Accuracy: 95.00% | Cost: 0.1569
# Epoch: 285 | Accuracy: 100.00% | Cost: 0.0293
# Epoch: 204 | Accuracy: 99.20% | Cost: 0.0863
# Epoch: 380 | Accuracy: 98.00% | Cost: 0.0884
# Epoch: 356 | Accuracy: 98.20% | Cost: 0.0880
# Epoch: 034 | Accuracy: 63.20% | Cost: 0.6922
# Epoch: 234 | Accuracy: 99.20% | Cost: 0.0669
# Epoch: 270 | Accuracy: 96.60% | Cost: 0.1413
# Epoch: 209 | Accuracy: 100.00% | Cost: 0.0445
# Epoch: 398 | Accuracy: 99.60% | Cost: 0.0460
# Epoch: 337 | Accuracy: 99.80% | Cost: 0.0268
# Epoch: 204 | Accuracy: 100.00% | Cost: 0.0505
# Epoch: 162 | Accuracy: 99.80% | Cost: 0.0606
# Epoch: 223 | Accuracy: 99.80% | Cost: 0.0493
# Epoch: 201 | Accuracy: 100.00% | Cost: 0.0475
# Epoch: 330 | Accuracy: 99.60% | Cost: 0.0441
# Epoch: 232 | Accuracy: 99.40% | Cost: 0.0533
# Epoch: 382 | Accuracy: 99.60% | Cost: 0.0272
# Epoch: 201 | Accuracy: 100.00% | Cost: 0.0467
# Epoch: 116 | Accuracy: 100.00% | Cost: 0.0379
# Epoch: 161 | Accuracy: 100.00% | Cost: 0.0536
# Epoch: 275 | Accuracy: 100.00% | Cost: 0.0198
# Epoch: 322 | Accuracy: 100.00% | Cost: 0.0128
# Epoch: 344 | Accuracy: 100.00% | Cost: 0.0110
# Epoch: 178 | Accuracy: 100.00% | Cost: 0.0203
# Epoch: 146 | Accuracy: 100.00% | Cost: 0.0373
# Epoch: 170 | Accuracy: 100.00% | Cost: 0.0402
# Epoch: 125 | Accuracy: 100.00% | Cost: 0.0590
# Epoch: 129 | Accuracy: 100.00% | Cost: 0.0393
# Epoch: 210 | Accuracy: 99.80% | Cost: 0.0285
# Epoch: 151 | Accuracy: 99.80% | Cost: 0.0458
# Epoch: 151 | Accuracy: 100.00% | Cost: 0.0248
# Epoch: 118 | Accuracy: 100.00% | Cost: 0.0384
# Epoch: 123 | Accuracy: 100.00% | Cost: 0.0858
# Epoch: 140 | Accuracy: 100.00% | Cost: 0.0196
# Epoch: 129 | Accuracy: 100.00% | Cost: 0.0343
# Epoch: 122 | Accuracy: 100.00% | Cost: 0.0543
# Epoch: 102 | Accuracy: 100.00% | Cost: 0.0638
# Epoch: 102 | Accuracy: 100.00% | Cost: 0.0791
# Epoch: 098 | Accuracy: 100.00% | Cost: 0.0562
# Epoch: 097 | Accuracy: 100.00% | Cost: 0.0510
# Epoch: 093 | Accuracy: 100.00% | Cost: 0.0420
# Epoch: 082 | Accuracy: 100.00% | Cost: 0.0742
# Epoch: 107 | Accuracy: 100.00% | Cost: 0.0479
# Epoch: 094 | Accuracy: 100.00% | Cost: 0.0769
# Epoch: 122 | Accuracy: 100.00% | Cost: 0.0686
# Epoch: 100 | Accuracy: 100.00% | Cost: 0.0638
# Epoch: 093 | Accuracy: 100.00% | Cost: 0.0625
# Epoch: 095 | Accuracy: 100.00% | Cost: 0.0604
# Epoch: 088 | Accuracy: 100.00% | Cost: 0.0793
# Epoch: 088 | Accuracy: 100.00% | Cost: 0.0631
# Epoch: 111 | Accuracy: 100.00% | Cost: 0.0334
# Epoch: 072 | Accuracy: 100.00% | Cost: 0.1117
# Epoch: 076 | Accuracy: 100.00% | Cost: 0.0688
# Epoch: 075 | Accuracy: 100.00% | Cost: 0.0921
# Epoch: 088 | Accuracy: 100.00% | Cost: 0.0616
# Epoch: 084 | Accuracy: 100.00% | Cost: 0.0629
# Epoch: 083 | Accuracy: 100.00% | Cost: 0.0656
# Epoch: 091 | Accuracy: 100.00% | Cost: 0.0375
# Epoch: 070 | Accuracy: 100.00% | Cost: 0.0699
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0855
# Epoch: 068 | Accuracy: 100.00% | Cost: 0.1091
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0463
# Epoch: 089 | Accuracy: 100.00% | Cost: 0.0650
# Epoch: 072 | Accuracy: 100.00% | Cost: 0.0794
# Epoch: 079 | Accuracy: 100.00% | Cost: 0.0786
# Epoch: 093 | Accuracy: 100.00% | Cost: 0.0434
# Epoch: 077 | Accuracy: 100.00% | Cost: 0.0776
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.0813
# Epoch: 055 | Accuracy: 100.00% | Cost: 0.1144
# Epoch: 064 | Accuracy: 100.00% | Cost: 0.1023
# Epoch: 044 | Accuracy: 100.00% | Cost: 0.1712
# Epoch: 067 | Accuracy: 100.00% | Cost: 0.0557
# Epoch: 046 | Accuracy: 100.00% | Cost: 0.2428
# Epoch: 058 | Accuracy: 100.00% | Cost: 0.0885
# Epoch: 060 | Accuracy: 100.00% | Cost: 0.1055
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.1063
# Epoch: 057 | Accuracy: 100.00% | Cost: 0.1267
# Epoch: 035 | Accuracy: 100.00% | Cost: 0.3005
# Epoch: 043 | Accuracy: 100.00% | Cost: 0.1793
# Epoch: 025 | Accuracy: 100.00% | Cost: 0.4475
# Epoch: 049 | Accuracy: 100.00% | Cost: 0.1166
# Epoch: 044 | Accuracy: 100.00% | Cost: 0.2166
# Epoch: 033 | Accuracy: 100.00% | Cost: 0.2893
# Epoch: 028 | Accuracy: 100.00% | Cost: 0.3470
# Epoch: 025 | Accuracy: 100.00% | Cost: 0.4424
# Epoch: 054 | Accuracy: 100.00% | Cost: 0.0802
# Epoch: 050 | Accuracy: 100.00% | Cost: 0.0924
# Time elapsed: 43.40 min
